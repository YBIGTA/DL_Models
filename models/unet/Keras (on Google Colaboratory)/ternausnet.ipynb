# %% [markdown]
# <center><h1>U-net Architecture on Keras</h1></center>

# %% [markdown]
# # Import

# %%
from keras.models import Model, Input
from keras.layers import Conv2D, MaxPooling2D, concatenate, UpSampling2D, Dropout, Cropping2D, Softmax
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Setting

# %%
image_shape = [256, 256, 3]

# %%
keep_prob = 0.5    # Dropout rate

# %%
num_of_classes = 80

# %% [markdown]
# # Model

# %%
def u_net_256(image_shape, keep_prob, num_of_classes):
  
  # Contracting Path
  
  input_image = Input(image_shape)
  
  conv1_1 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv1_1')(input_image)
  conv1_2 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv1_2')(conv1_1)
  
  pool_1 = MaxPooling2D(name = 'pool_1')(conv1_2)
  
  conv2_1 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv2_1')(pool_1)
  conv2_2 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv2_2')(conv2_1)
  
  pool_2 = MaxPooling2D(name = 'pool_2')(conv2_2)
  
  conv3_1 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv3_1')(pool_2)
  conv3_2 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv3_2')(conv3_1)
  
  pool_3 = MaxPooling2D(name = 'pool_3')(conv3_2)
  
  conv4_1 = Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv4_1')(pool_3)
  conv4_2 = Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv4_2')(conv4_1)
  
  
  
  # Expanding Path
  
  upconv5_1 = UpSampling2D(name = 'upconv5_1')(conv4_2)
  upconv5_2 = Conv2D(filters = 128, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv5_2')(upconv5_1)
  concat_5 = concatenate([upconv5_2, conv3_2], axis = 3, name = 'concat_5')
  
  conv5_1 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv5_1')(concat_5)
  conv5_2 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv5_2')(conv5_1)
  
  
  upconv6_1 = UpSampling2D(name = 'upconv6_1')(conv5_2)
  upconv6_2 = Conv2D(filters = 64, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv6_2')(upconv6_1)
  concat_6 = concatenate([upconv6_2, conv2_2], axis = 3, name = 'concat_6')
  
  conv6_1 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv6_1')(concat_6)
  conv6_2 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv6_2')(conv6_1)
  
  upconv7_1 = UpSampling2D(name = 'upconv7_1')(conv6_2)
  upconv7_2 = Conv2D(filters = 32, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv7_2')(upconv7_1)
  concat_7 = concatenate([upconv7_2, conv1_2], axis = 3, name = 'concat_7')
  
  conv7_1 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv7_1')(concat_7)
  conv7_2 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv7_2')(conv7_1)
  
  conv8 = Conv2D(filters = num_of_classes, kernel_size = (1, 1), activation = 'softmax', name = 'conv8')(conv7_2)
  
  model = Model(inputs = input_image, outputs = conv8, name = 'model')
  
  return model

# %%
u_net = u_net_256(image_shape, keep_prob, num_of_classes)

# %%
u_net.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv1_1 (Conv2D)                (None, 256, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv1_2 (Conv2D)                (None, 256, 256, 32) 9248        conv1_1[0][0]
# __________________________________________________________________________________________________
# pool_1 (MaxPooling2D)           (None, 128, 128, 32) 0           conv1_2[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv2D)                (None, 128, 128, 64) 18496       pool_1[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv2D)                (None, 128, 128, 64) 36928       conv2_1[0][0]
# __________________________________________________________________________________________________
# pool_2 (MaxPooling2D)           (None, 64, 64, 64)   0           conv2_2[0][0]
# __________________________________________________________________________________________________
# conv3_1 (Conv2D)                (None, 64, 64, 128)  73856       pool_2[0][0]
# __________________________________________________________________________________________________
# conv3_2 (Conv2D)                (None, 64, 64, 128)  147584      conv3_1[0][0]
# __________________________________________________________________________________________________
# pool_3 (MaxPooling2D)           (None, 32, 32, 128)  0           conv3_2[0][0]
# __________________________________________________________________________________________________
# conv4_1 (Conv2D)                (None, 32, 32, 256)  295168      pool_3[0][0]
# __________________________________________________________________________________________________
# conv4_2 (Conv2D)                (None, 32, 32, 256)  590080      conv4_1[0][0]
# __________________________________________________________________________________________________
# upconv5_1 (UpSampling2D)        (None, 64, 64, 256)  0           conv4_2[0][0]
# __________________________________________________________________________________________________
# upconv5_2 (Conv2D)              (None, 64, 64, 128)  131200      upconv5_1[0][0]
# __________________________________________________________________________________________________
# concat_5 (Concatenate)          (None, 64, 64, 256)  0           upconv5_2[0][0]
#                                                                  conv3_2[0][0]
# __________________________________________________________________________________________________
# conv5_1 (Conv2D)                (None, 64, 64, 128)  295040      concat_5[0][0]
# __________________________________________________________________________________________________
# conv5_2 (Conv2D)                (None, 64, 64, 128)  147584      conv5_1[0][0]
# __________________________________________________________________________________________________
# upconv6_1 (UpSampling2D)        (None, 128, 128, 128 0           conv5_2[0][0]
# __________________________________________________________________________________________________
# upconv6_2 (Conv2D)              (None, 128, 128, 64) 32832       upconv6_1[0][0]
# __________________________________________________________________________________________________
# concat_6 (Concatenate)          (None, 128, 128, 128 0           upconv6_2[0][0]
#                                                                  conv2_2[0][0]
# __________________________________________________________________________________________________
# conv6_1 (Conv2D)                (None, 128, 128, 64) 73792       concat_6[0][0]
# __________________________________________________________________________________________________
# conv6_2 (Conv2D)                (None, 128, 128, 64) 36928       conv6_1[0][0]
# __________________________________________________________________________________________________
# upconv7_1 (UpSampling2D)        (None, 256, 256, 64) 0           conv6_2[0][0]
# __________________________________________________________________________________________________
# upconv7_2 (Conv2D)              (None, 256, 256, 32) 8224        upconv7_1[0][0]
# __________________________________________________________________________________________________
# concat_7 (Concatenate)          (None, 256, 256, 64) 0           upconv7_2[0][0]
#                                                                  conv1_2[0][0]
# __________________________________________________________________________________________________
# conv7_1 (Conv2D)                (None, 256, 256, 32) 18464       concat_7[0][0]
# __________________________________________________________________________________________________
# conv7_2 (Conv2D)                (None, 256, 256, 32) 9248        conv7_1[0][0]
# __________________________________________________________________________________________________
# conv8 (Conv2D)                  (None, 256, 256, 80) 2640        conv7_2[0][0]
# ==================================================================================================
# Total params: 1,928,208
# Trainable params: 1,928,208
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def u_net_model(image_shape, keep_prob, num_of_classes):
  
  # Contracting Path
  
  input_image = Input(image_shape)
  
  conv1_1 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv1_1')(input_image)
  conv1_2 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv1_2')(conv1_1)
  
  pool_1 = MaxPooling2D(name = 'pool_1')(conv1_2)
  
  conv2_1 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv2_1')(pool_1)
  conv2_2 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv2_2')(conv2_1)
  
  pool_2 = MaxPooling2D(name = 'pool_2')(conv2_2)
  
  conv3_1 = Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv3_1')(pool_2)
  conv3_2 = Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv3_2')(conv3_1)
  
  pool_3 = MaxPooling2D(name = 'pool_3')(conv3_2)
  
  conv4_1 = Conv2D(filters = 512, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv4_1')(pool_3)
  conv4_2 = Conv2D(filters = 512, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv4_2')(conv4_1)
  drop_4 = Dropout(keep_prob, name = 'drop_4')(conv4_2)
  
  pool_4 = MaxPooling2D(name = 'pool_4')(drop_4)
  
  conv5_1 = Conv2D(filters = 1024, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv5_1')(pool_4)
  conv5_2 = Conv2D(filters = 1024, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv5_2')(conv5_1)
  drop_5 = Dropout(keep_prob, name = 'drop_5')(conv5_2)
  
  
  
  # Expanding Path
  
  upconv6_1 = UpSampling2D(name = 'upconv6_1')(drop_5)
  upconv6_2 = Conv2D(filters = 512, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv6_2')(upconv6_1)
  cropped_4 = Cropping2D(((4, 4)), name = 'cropped_4')(drop_4)
  concat_6 = concatenate([upconv6_2, cropped_4], axis = 3, name = 'concat_6')
  
  conv6_1 = Conv2D(filters = 512, kernel_size = (3, 3), activation = 'relu', name = 'conv6_1')(concat_6)
  conv6_2 = Conv2D(filters = 512, kernel_size = (3, 3), activation = 'relu', name = 'conv6_2')(conv6_1)
  
  upconv7_1 = UpSampling2D(name = 'upconv7_1')(conv6_2)
  upconv7_2 = Conv2D(filters = 256, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv7_2')(upconv7_1)
  cropped_3 = Cropping2D((16, 16), name = 'cropped_3')(conv3_2)
  concat_7 = concatenate([upconv7_2, cropped_3], axis = 3, name = 'concat_7')
  
  conv7_1 = Conv2D(filters = 256, kernel_size = (3, 3), activation = 'relu', name = 'conv7_1')(concat_7)
  conv7_2 = Conv2D(filters = 256, kernel_size = (3, 3), activation = 'relu', name = 'conv7_2')(conv7_1)
  
  upconv8_1 = UpSampling2D(name = 'upconv8_1')(conv7_2)
  upconv8_2 = Conv2D(filters = 128, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv8_2')(upconv8_1)
  cropped_2 = Cropping2D((40, 40), name = 'cropped_2')(conv2_2)
  concat_8 = concatenate([upconv8_2, cropped_2], axis = 3, name = 'concat_8')
  
  conv8_1 = Conv2D(filters = 128, kernel_size = (3, 3), activation = 'relu', name = 'conv8_1')(concat_8)
  conv8_2 = Conv2D(filters = 128, kernel_size = (3, 3), activation = 'relu', name = 'conv8_2')(conv8_1)
  
  upconv9_1 = UpSampling2D(name = 'upconv9_1')(conv8_2)
  upconv9_2 = Conv2D(filters = 64, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv9_2')(upconv9_1)
  cropped_1 = Cropping2D((88, 88), name = 'cropped_1')(conv1_2)
  concat_9 = concatenate([upconv9_2, cropped_1], axis = 3, name = 'concat_9')
  
  conv9_1 = Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu', name = 'conv9_1')(concat_9)
  conv9_2 = Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu', name = 'conv9_2')(conv9_1)
  
  conv10 = Conv2D(filters = num_of_classes, kernel_size = (1, 1), activation = 'sigmoid', name = 'conv10')(conv9_2)
   
  
  model = Model(inputs = input_image, outputs = conv10, name = 'model')
  
  return model

# %%
# model = u_net_model(image_shape, keep_prob, num_of_classes)

# %%
# model.summary()

# %% [markdown]
# # COCO Dataset

# %%
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab

from glob import glob
from PIL import Image

# %%
# !pip install Cython
# !pip install pycocotools
# Out:
# Collecting Cython
#   Downloading https://files.pythonhosted.org/packages/19/8e/32b280abb0947a96cdbb8329fb2014851a21fc1d099009f946ea8a8202c3/Cython-0.28.5-cp36-cp36m-manylinux1_x86_64.whl (3.4MB)
#     100% |████████████████████████████████| 3.4MB 984kB/s
# Installing collected packages: Cython
# Successfully installed Cython-0.28.5
# Collecting pycocotools
#   Downloading https://files.pythonhosted.org/packages/96/84/9a07b1095fd8555ba3f3d519517c8743c2554a245f9476e5e39869f948d2/pycocotools-2.0.0.tar.gz (1.5MB)
#     100% |████████████████████████████████| 1.5MB 15.0MB/s
# Building wheels for collected packages: pycocotools
# done
#   Stored in directory: /root/.cache/pip/wheels/dc/e6/36/0e1ae88c868eb42d3f92181b1c9bbd0b217a7ec3da6bd62e55
# Successfully built pycocotools
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.0

# %%
from pycocotools.coco import COCO

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
cd /gdrive/My \Drive
# Out:
# /gdrive/My Drive

# %%
val_img_files = glob('cocoapi/images/' + '*.jp*g')
print(val_img_files[:3])
# Out:
# ['cocoapi/images/000000136355.jpg', 'cocoapi/images/000000077460.jpg', 'cocoapi/images/000000513484.jpg']

# %%
val_img_Ids = [int(id[-10:-4]) for id in val_img_files]
print(val_img_Ids[:3])
# Out:
# [136355, 77460, 513484]

# %%
dataDir='cocoapi'
dataType='val2017'
annFile='{}/annotations/instances_{}.json'.format(dataDir,dataType)
coco = COCO(annotation_file = annFile)
# Out:
# loading annotations into memory...
# Done (t=3.81s)
# creating index...
# index created!

# %%
cats = coco.loadCats(coco.getCatIds())

# %%
categories = []

for cat in cats:
  categories.append(cat['name'])

# %%
print(len(categories))
# Out:
# 80

# %%
cat_Ids = [cat['id'] for cat in cats]

# %%
def index_matching(cat_id, cat_Ids = cat_Ids, categories = categories):
  index = cat_Ids.index(cat_id)
  
  return categories[index], index, cat_id

# %%
def img_loader(imgIds, val_img_files):
  for img_path in val_img_files:
    if str(imgIds) in img_path:
      return img_path

# %%
def gt_maker(imgId, step, val_img_files = val_img_files, num_of_classes = num_of_classes, val_img_Ids = val_img_Ids):
  anns = coco.loadAnns(coco.getAnnIds(imgIds = [imgId]))
  annIds = coco.getAnnIds(imgIds = [imgId])
  img = image.img_to_array(Image.open(img_loader(imgId, val_img_files)).resize((256, 256)))
  
  
  if img.shape == (256, 256, 3):
  # mask = np.zeros(list(img.shape[:2]) + [num_of_classes])
    mask_1d = coco.annToMask(anns[0])
    
    for i in range(len(anns)):
      cat_id = anns[i]['category_id']
      _, index, _ = index_matching(cat_id)
      index -= 1
    
      mask_ann = coco.annToMask(anns[i])
    # mask_ann_re = image.img_to_array(Image.fromarray(mask_ann).resize((388, 388)))
    
      mask_1d += mask_ann * cat_id
    
    # mask_expand = np.expand_dims(mask_ann_re, axis = 2)
    
    # mask_pad = np.pad(mask_ann_re, pad_width = ((0, 0), (0, 0), (0, num_of_classes - 1)), mode = 'constant')
    
    # arridx = np.where(mask_pad == 1)
    # mask_pad[arridx] = 0
    # mask_pad[(arridx[0], arridx[1], arridx[2] + index)] = 1
    # mask += mask_pad
  
  
    mask_1d = image.img_to_array(Image.fromarray(mask_1d).resize((256, 256)))
    
    if step % 100 == 0:
      print("End : GT Image of Id", format(imgId, '^7'), "| shape = {0}".format(mask_1d.shape), "| step : [{0} / {1}]".format(step + 1, len(val_img_Ids)))
    
  return mask_1d, img

# %%
input_img = []
gt_img = []
error_img = []

for i, imgId in enumerate(val_img_Ids):
  try:
    gt, img = gt_maker(imgId, i)
    gt_img.append(gt)
    input_img.append(img)
  except Exception as ex:
    print("step : {0} [id : {1}] Error!!".format(i, imgId))
    error_img.append(imgId)
# Out:
# End : GT Image of Id 136355  | shape = (256, 256, 1) | step : [1 / 2327]
# step : 24 [id : 98497] Error!!
# step : 49 [id : 344611] Error!!
# End : GT Image of Id 568195  | shape = (256, 256, 1) | step : [101 / 2327]
# step : 185 [id : 374727] Error!!
# End : GT Image of Id 117645  | shape = (256, 256, 1) | step : [201 / 2327]
# step : 244 [id : 141671] Error!!
# End : GT Image of Id 205834  | shape = (256, 256, 1) | step : [301 / 2327]
# End : GT Image of Id 282912  | shape = (256, 256, 1) | step : [401 / 2327]
# step : 421 [id : 353180] Error!!
# End : GT Image of Id 334399  | shape = (256, 256, 1) | step : [501 / 2327]
# End : GT Image of Id 252216  | shape = (256, 256, 1) | step : [601 / 2327]
# step : 694 [id : 550939] Error!!
# End : GT Image of Id 175251  | shape = (256, 256, 1) | step : [701 / 2327]
# step : 786 [id : 458790] Error!!
# End : GT Image of Id 498919  | shape = (256, 256, 1) | step : [801 / 2327]
# step : 809 [id : 528977] Error!!
# step : 812 [id : 536343] Error!!
# step : 839 [id : 308391] Error!!
# End : GT Image of Id 145020  | shape = (256, 256, 1) | step : [901 / 2327]
# step : 982 [id : 25593] Error!!
# End : GT Image of Id  66635  | shape = (256, 256, 1) | step : [1001 / 2327]
# End : GT Image of Id 209530  | shape = (256, 256, 1) | step : [1101 / 2327]
# step : 1199 [id : 310622] Error!!
# End : GT Image of Id 359219  | shape = (256, 256, 1) | step : [1201 / 2327]
# step : 1202 [id : 404601] Error!!
# End : GT Image of Id  84170  | shape = (256, 256, 1) | step : [1301 / 2327]
# step : 1304 [id : 121153] Error!!
# End : GT Image of Id 156372  | shape = (256, 256, 1) | step : [1401 / 2327]
# step : 1413 [id : 61418] Error!!
# step : 1499 [id : 200152] Error!!
# End : GT Image of Id 177861  | shape = (256, 256, 1) | step : [1501 / 2327]
# End : GT Image of Id 246308  | shape = (256, 256, 1) | step : [1601 / 2327]
# End : GT Image of Id  22479  | shape = (256, 256, 1) | step : [1701 / 2327]
# step : 1714 [id : 268996] Error!!
# End : GT Image of Id 305695  | shape = (256, 256, 1) | step : [1801 / 2327]
# step : 1801 [id : 267946] Error!!
# step : 1806 [id : 382734] Error!!
# step : 1808 [id : 198915] Error!!
# step : 1899 [id : 431848] Error!!
# End : GT Image of Id 256916  | shape = (256, 256, 1) | step : [1901 / 2327]
# step : 1934 [id : 402096] Error!!
# End : GT Image of Id  79144  | shape = (256, 256, 1) | step : [2001 / 2327]
# step : 2019 [id : 176701] Error!!
# step : 2070 [id : 240767] Error!!
# End : GT Image of Id 128476  | shape = (256, 256, 1) | step : [2101 / 2327]
# step : 2171 [id : 560371] Error!!
# End : GT Image of Id 388215  | shape = (256, 256, 1) | step : [2201 / 2327]
# step : 2287 [id : 209222] Error!!
# step : 2294 [id : 41488] Error!!
# End : GT Image of Id 352491  | shape = (256, 256, 1) | step : [2301 / 2327]
# step : 2317 [id : 481404] Error!!

# %%
# np.save('gt_img_116.npy', np.asarray(gt_img))

# %%
input_array = np.array(input_img)
gt_array = np.array(gt_img)

# %%
print(input_array.shape, gt_array.shape)
# Out:
# (2299, 256, 256, 3) (2299, 256, 256, 1)

# %% [markdown]
# # Compile

# %%
import keras.backend as K
import tensorflow as tf

def custom_cross_entropy(y_true, y_pred):
	
  true_shape = K.shape(y_true)
  pred_shape = K.shape(y_pred)
  
  # reshape such that w and h dim are multiplied together
  y_true_reshaped = K.reshape( y_true, tf.stack( [-1, true_shape[1] * true_shape[2], true_shape[-1]] ) )
  y_pred_reshaped = K.reshape( y_pred, tf.stack( [-1, pred_shape[1] * pred_shape[2], pred_shape[-1]] ) )

	# correctly classified
  y_true_reshaped = tf.cast(y_true_reshaped, tf.int32)
  y_true_one = K.one_hot(y_true_reshaped, num_classes = pred_shape[-1])
  y_true_one = K.reshape(y_true_one, tf.stack( [-1, K.shape(y_true_one)[1], pred_shape[-1]]))
  
  
  return -K.mean(y_true_one * K.log(y_pred_reshaped))

# %%
import keras.backend as K
import tensorflow as tf

def mean_acc(y_true, y_pred):
	
  true_shape = K.shape(y_true)
  pred_shape = K.shape(y_pred)
  
  # reshape such that w and h dim are multiplied together
  y_true_reshaped = K.reshape( y_true, tf.stack( [-1, true_shape[1] * true_shape[2], true_shape[-1]] ))
  y_pred_reshaped = K.reshape( y_pred, tf.stack( [-1, pred_shape[1] * pred_shape[2], pred_shape[-1]] ) )

	# correctly classified
  y_true_reshaped = tf.cast(y_true_reshaped, tf.int64)
  y_true_one = K.one_hot(y_true_reshaped, num_classes = pred_shape[-1])
  y_true_one = K.reshape(y_true_one, tf.stack( [-1, K.shape(y_true_one)[1], pred_shape[-1]]))
  
  y_pred_argmax = K.argmax(y_pred_reshaped, axis = 2)
  y_pred_argmax = K.reshape(y_pred_argmax, K.shape(y_true_reshaped))
  
  equal_entries = tf.cast(K.equal(y_true_reshaped, y_pred_argmax), tf.int64)

  correct_pixels_per_class = K.sum(equal_entries, axis=1)
  
  n_pixels_per_class = tf.cast(K.shape(equal_entries)[1] * K.shape(equal_entries)[2], tf.int64)

  acc = correct_pixels_per_class / n_pixels_per_class
  # acc_mask = tf.is_finite(acc)
  # acc_masked = tf.boolean_mask(acc,acc_mask)
  
  return acc

# %%
u_net.compile(optimizer = 'sgd', loss = custom_cross_entropy, metrics = [mean_acc])

# %% [markdown]
# # Training

# %%
r = u_net.fit(x = input_array, y = gt_array, validation_split = 0.3, epochs = 100)
# Out:
# Train on 1609 samples, validate on 690 samples
# Epoch 1/100
# 1609/1609 [==============================] - 122s 76ms/step - loss: 0.0482 - mean_acc: 0.3590 - val_loss: 0.0360 - val_mean_acc: 0.5700
# Epoch 2/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0332 - mean_acc: 0.6141 - val_loss: 0.0334 - val_mean_acc: 0.6241
# Epoch 3/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0313 - mean_acc: 0.6479 - val_loss: 0.0320 - val_mean_acc: 0.6423
# Epoch 4/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0302 - mean_acc: 0.6656 - val_loss: 0.0311 - val_mean_acc: 0.6594
# Epoch 5/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0295 - mean_acc: 0.6754 - val_loss: 0.0304 - val_mean_acc: 0.6649
# Epoch 6/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0290 - mean_acc: 0.6808 - val_loss: 0.0299 - val_mean_acc: 0.6690
# Epoch 7/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0286 - mean_acc: 0.6851 - val_loss: 0.0295 - val_mean_acc: 0.6722
# Epoch 8/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0282 - mean_acc: 0.6884 - val_loss: 0.0292 - val_mean_acc: 0.6730
# Epoch 9/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0280 - mean_acc: 0.6913 - val_loss: 0.0289 - val_mean_acc: 0.6785
# Epoch 10/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0277 - mean_acc: 0.6942 - val_loss: 0.0287 - val_mean_acc: 0.6822
# Epoch 11/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0275 - mean_acc: 0.6964 - val_loss: 0.0286 - val_mean_acc: 0.6845
# Epoch 12/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0274 - mean_acc: 0.6980 - val_loss: 0.0283 - val_mean_acc: 0.6842
# Epoch 13/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0272 - mean_acc: 0.6989 - val_loss: 0.0282 - val_mean_acc: 0.6863
# Epoch 14/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0271 - mean_acc: 0.7001 - val_loss: 0.0281 - val_mean_acc: 0.6871
# Epoch 15/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0269 - mean_acc: 0.7008 - val_loss: 0.0279 - val_mean_acc: 0.6879
# Epoch 16/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0268 - mean_acc: 0.7015 - val_loss: 0.0278 - val_mean_acc: 0.6863
# Epoch 17/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0267 - mean_acc: 0.7019 - val_loss: 0.0276 - val_mean_acc: 0.6884
# Epoch 18/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0265 - mean_acc: 0.7024 - val_loss: 0.0275 - val_mean_acc: 0.6890
# Epoch 19/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0264 - mean_acc: 0.7029 - val_loss: 0.0274 - val_mean_acc: 0.6894
# Epoch 20/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0263 - mean_acc: 0.7033 - val_loss: 0.0273 - val_mean_acc: 0.6887
# Epoch 21/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0262 - mean_acc: 0.7035 - val_loss: 0.0272 - val_mean_acc: 0.6900
# Epoch 22/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0262 - mean_acc: 0.7039 - val_loss: 0.0271 - val_mean_acc: 0.6902
# Epoch 23/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0261 - mean_acc: 0.7041 - val_loss: 0.0270 - val_mean_acc: 0.6904
# Epoch 24/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0260 - mean_acc: 0.7043 - val_loss: 0.0270 - val_mean_acc: 0.6911
# Epoch 25/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0259 - mean_acc: 0.7046 - val_loss: 0.0268 - val_mean_acc: 0.6910
# Epoch 26/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0258 - mean_acc: 0.7048 - val_loss: 0.0268 - val_mean_acc: 0.6912
# Epoch 27/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0258 - mean_acc: 0.7050 - val_loss: 0.0267 - val_mean_acc: 0.6915
# Epoch 28/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0257 - mean_acc: 0.7051 - val_loss: 0.0268 - val_mean_acc: 0.6919
# Epoch 29/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0256 - mean_acc: 0.7053 - val_loss: 0.0266 - val_mean_acc: 0.6918
# Epoch 30/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0256 - mean_acc: 0.7054 - val_loss: 0.0265 - val_mean_acc: 0.6917
# Epoch 31/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0255 - mean_acc: 0.7055 - val_loss: 0.0264 - val_mean_acc: 0.6920
# Epoch 32/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0254 - mean_acc: 0.7057 - val_loss: 0.0265 - val_mean_acc: 0.6923
# Epoch 33/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0254 - mean_acc: 0.7058 - val_loss: 0.0264 - val_mean_acc: 0.6920
# Epoch 34/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0253 - mean_acc: 0.7059 - val_loss: 0.0262 - val_mean_acc: 0.6924
# Epoch 35/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0253 - mean_acc: 0.7060 - val_loss: 0.0262 - val_mean_acc: 0.6925
# Epoch 36/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0252 - mean_acc: 0.7061 - val_loss: 0.0261 - val_mean_acc: 0.6926
# Epoch 37/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0252 - mean_acc: 0.7062 - val_loss: 0.0261 - val_mean_acc: 0.6926
# Epoch 38/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0251 - mean_acc: 0.7062 - val_loss: 0.0261 - val_mean_acc: 0.6928
# Epoch 39/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0251 - mean_acc: 0.7063 - val_loss: 0.0260 - val_mean_acc: 0.6926
# Epoch 40/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0250 - mean_acc: 0.7063 - val_loss: 0.0260 - val_mean_acc: 0.6927
# Epoch 41/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0250 - mean_acc: 0.7064 - val_loss: 0.0259 - val_mean_acc: 0.6930
# Epoch 42/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0249 - mean_acc: 0.7065 - val_loss: 0.0258 - val_mean_acc: 0.6929
# Epoch 43/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0249 - mean_acc: 0.7065 - val_loss: 0.0258 - val_mean_acc: 0.6930
# Epoch 44/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0248 - mean_acc: 0.7066 - val_loss: 0.0258 - val_mean_acc: 0.6931
# Epoch 45/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0248 - mean_acc: 0.7066 - val_loss: 0.0257 - val_mean_acc: 0.6931
# Epoch 46/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0247 - mean_acc: 0.7066 - val_loss: 0.0257 - val_mean_acc: 0.6930
# Epoch 47/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0247 - mean_acc: 0.7067 - val_loss: 0.0256 - val_mean_acc: 0.6931
# Epoch 48/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0247 - mean_acc: 0.7067 - val_loss: 0.0256 - val_mean_acc: 0.6932
# Epoch 49/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0246 - mean_acc: 0.7067 - val_loss: 0.0258 - val_mean_acc: 0.6930
# Epoch 50/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0246 - mean_acc: 0.7067 - val_loss: 0.0255 - val_mean_acc: 0.6933
# Epoch 51/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0245 - mean_acc: 0.7068 - val_loss: 0.0257 - val_mean_acc: 0.6931
# Epoch 52/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0245 - mean_acc: 0.7068 - val_loss: 0.0257 - val_mean_acc: 0.6935
# Epoch 53/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0245 - mean_acc: 0.7068 - val_loss: 0.0254 - val_mean_acc: 0.6933
# Epoch 54/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0244 - mean_acc: 0.7069 - val_loss: 0.0254 - val_mean_acc: 0.6934
# Epoch 55/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0244 - mean_acc: 0.7069 - val_loss: 0.0254 - val_mean_acc: 0.6935
# Epoch 56/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0244 - mean_acc: 0.7069 - val_loss: 0.0254 - val_mean_acc: 0.6935
# Epoch 57/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0243 - mean_acc: 0.7069 - val_loss: 0.0254 - val_mean_acc: 0.6935
# Epoch 58/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0243 - mean_acc: 0.7069 - val_loss: 0.0252 - val_mean_acc: 0.6935
# Epoch 59/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0243 - mean_acc: 0.7069 - val_loss: 0.0255 - val_mean_acc: 0.6932
# Epoch 60/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0242 - mean_acc: 0.7070 - val_loss: 0.0251 - val_mean_acc: 0.6934
# Epoch 61/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0241 - mean_acc: 0.7069 - val_loss: 0.0251 - val_mean_acc: 0.6935
# Epoch 62/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0241 - mean_acc: 0.7070 - val_loss: 0.0250 - val_mean_acc: 0.6935
# Epoch 63/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0241 - mean_acc: 0.7070 - val_loss: 0.0250 - val_mean_acc: 0.6935
# Epoch 64/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0240 - mean_acc: 0.7070 - val_loss: 0.0249 - val_mean_acc: 0.6935
# Epoch 65/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0240 - mean_acc: 0.7070 - val_loss: 0.0249 - val_mean_acc: 0.6935
# Epoch 66/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0240 - mean_acc: 0.7070 - val_loss: 0.0249 - val_mean_acc: 0.6936
# Epoch 67/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0239 - mean_acc: 0.7070 - val_loss: 0.0248 - val_mean_acc: 0.6936
# Epoch 68/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0239 - mean_acc: 0.7070 - val_loss: 0.0248 - val_mean_acc: 0.6936
# Epoch 69/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0238 - mean_acc: 0.7070 - val_loss: 0.0248 - val_mean_acc: 0.6935
# Epoch 70/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0238 - mean_acc: 0.7071 - val_loss: 0.0247 - val_mean_acc: 0.6936
# Epoch 71/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0238 - mean_acc: 0.7071 - val_loss: 0.0248 - val_mean_acc: 0.6936
# Epoch 72/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0238 - mean_acc: 0.7071 - val_loss: 0.0249 - val_mean_acc: 0.6937
# Epoch 73/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0237 - mean_acc: 0.7071 - val_loss: 0.0246 - val_mean_acc: 0.6936
# Epoch 74/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0237 - mean_acc: 0.7071 - val_loss: 0.0246 - val_mean_acc: 0.6936
# Epoch 75/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0237 - mean_acc: 0.7071 - val_loss: 0.0245 - val_mean_acc: 0.6936
# Epoch 76/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0236 - mean_acc: 0.7071 - val_loss: 0.0245 - val_mean_acc: 0.6936
# Epoch 77/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0236 - mean_acc: 0.7071 - val_loss: 0.0244 - val_mean_acc: 0.6936
# Epoch 78/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0235 - mean_acc: 0.7071 - val_loss: 0.0244 - val_mean_acc: 0.6936
# Epoch 79/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0235 - mean_acc: 0.7071 - val_loss: 0.0248 - val_mean_acc: 0.6937
# Epoch 80/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0235 - mean_acc: 0.7071 - val_loss: 0.0247 - val_mean_acc: 0.6934
# Epoch 81/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0235 - mean_acc: 0.7071 - val_loss: 0.0245 - val_mean_acc: 0.6935
# Epoch 82/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0234 - mean_acc: 0.7071 - val_loss: 0.0250 - val_mean_acc: 0.6933
# Epoch 83/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0234 - mean_acc: 0.7071 - val_loss: 0.0242 - val_mean_acc: 0.6937
# Epoch 84/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0233 - mean_acc: 0.7071 - val_loss: 0.0241 - val_mean_acc: 0.6936
# Epoch 85/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0233 - mean_acc: 0.7071 - val_loss: 0.0244 - val_mean_acc: 0.6937
# Epoch 86/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0233 - mean_acc: 0.7071 - val_loss: 0.0241 - val_mean_acc: 0.6936
# Epoch 87/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0232 - mean_acc: 0.7071 - val_loss: 0.0243 - val_mean_acc: 0.6937
# Epoch 88/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0232 - mean_acc: 0.7071 - val_loss: 0.0244 - val_mean_acc: 0.6938
# Epoch 89/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0232 - mean_acc: 0.7071 - val_loss: 0.0240 - val_mean_acc: 0.6937
# Epoch 90/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0231 - mean_acc: 0.7071 - val_loss: 0.0241 - val_mean_acc: 0.6937
# Epoch 91/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0231 - mean_acc: 0.7071 - val_loss: 0.0243 - val_mean_acc: 0.6938
# Epoch 92/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0231 - mean_acc: 0.7071 - val_loss: 0.0240 - val_mean_acc: 0.6937
# Epoch 93/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0230 - mean_acc: 0.7071 - val_loss: 0.0238 - val_mean_acc: 0.6936
# Epoch 94/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0230 - mean_acc: 0.7071 - val_loss: 0.0253 - val_mean_acc: 0.6929
# Epoch 95/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0229 - mean_acc: 0.7071 - val_loss: 0.0240 - val_mean_acc: 0.6937
# Epoch 96/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0230 - mean_acc: 0.7071 - val_loss: 0.0244 - val_mean_acc: 0.6938
# Epoch 97/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0229 - mean_acc: 0.7071 - val_loss: 0.0237 - val_mean_acc: 0.6936
# Epoch 98/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0229 - mean_acc: 0.7071 - val_loss: 0.0240 - val_mean_acc: 0.6938
# Epoch 99/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0228 - mean_acc: 0.7071 - val_loss: 0.0238 - val_mean_acc: 0.6937
# Epoch 100/100
# 1609/1609 [==============================] - 107s 67ms/step - loss: 0.0228 - mean_acc: 0.7071 - val_loss: 0.0236 - val_mean_acc: 0.6937

# %% [markdown]
# # Result

# %%
result_ex = u_net.predict(input_array[:10])
