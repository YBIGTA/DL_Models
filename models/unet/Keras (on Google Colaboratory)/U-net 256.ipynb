# %% [markdown]
# <center><h1>U-net Architecture on Keras</h1></center>

# %% [markdown]
# # Import

# %%
from keras.models import Model, Input
from keras.layers import Conv2D, MaxPooling2D, concatenate, UpSampling2D, Dropout, Cropping2D
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Setting

# %%
image_shape = [216, 256, 3]

# %%
keep_prob = 0.5    # Dropout rate

# %%
num_of_classes = 1

# %% [markdown]
# # Model

# %%
def u_net_256(image_shape, keep_prob, num_of_classes):
  
  # Contracting Path
  
  input_image = Input(image_shape)
  
  conv1_1 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv1_1')(input_image)
  conv1_2 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv1_2')(conv1_1)
  
  pool_1 = MaxPooling2D(name = 'pool_1')(conv1_2)
  
  conv2_1 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv2_1')(pool_1)
  conv2_2 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv2_2')(conv2_1)
  
  pool_2 = MaxPooling2D(name = 'pool_2')(conv2_2)
  
  conv3_1 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv3_1')(pool_2)
  conv3_2 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv3_2')(conv3_1)
  
  pool_3 = MaxPooling2D(name = 'pool_3')(conv3_2)
  
  conv4_1 = Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv4_1')(pool_3)
  conv4_2 = Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv4_2')(conv4_1)
  
  
  
  # Expanding Path
  
  upconv5_1 = UpSampling2D(name = 'upconv5_1')(conv4_2)
  upconv5_2 = Conv2D(filters = 128, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv5_2')(upconv5_1)
  concat_5 = concatenate([upconv5_2, conv3_2], axis = 3, name = 'concat_5')
  
  conv5_1 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv5_1')(concat_5)
  conv5_2 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv5_2')(conv5_1)
  
  
  upconv6_1 = UpSampling2D(name = 'upconv6_1')(conv5_2)
  upconv6_2 = Conv2D(filters = 64, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv6_2')(upconv6_1)
  concat_6 = concatenate([upconv6_2, conv2_2], axis = 3, name = 'concat_6')
  
  conv6_1 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv6_1')(concat_6)
  conv6_2 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv6_2')(conv6_1)
  
  upconv7_1 = UpSampling2D(name = 'upconv7_1')(conv6_2)
  upconv7_2 = Conv2D(filters = 32, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv7_2')(upconv7_1)
  concat_7 = concatenate([upconv7_2, conv1_2], axis = 3, name = 'concat_7')
  
  conv7_1 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv7_1')(concat_7)
  conv7_2 = Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv7_2')(conv7_1)
  
  conv8 = Conv2D(filters = num_of_classes, kernel_size = (1, 1), activation = 'sigmoid', name = 'conv8')(conv7_2)
  
  model = Model(inputs = input_image, outputs = conv8, name = 'model')
  
  return model

# %%
u_net = u_net_256(image_shape, keep_prob, num_of_classes)

# %%
u_net.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 216, 256, 3)  0
# __________________________________________________________________________________________________
# conv1_1 (Conv2D)                (None, 216, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv1_2 (Conv2D)                (None, 216, 256, 32) 9248        conv1_1[0][0]
# __________________________________________________________________________________________________
# pool_1 (MaxPooling2D)           (None, 108, 128, 32) 0           conv1_2[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv2D)                (None, 108, 128, 64) 18496       pool_1[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv2D)                (None, 108, 128, 64) 36928       conv2_1[0][0]
# __________________________________________________________________________________________________
# pool_2 (MaxPooling2D)           (None, 54, 64, 64)   0           conv2_2[0][0]
# __________________________________________________________________________________________________
# conv3_1 (Conv2D)                (None, 54, 64, 128)  73856       pool_2[0][0]
# __________________________________________________________________________________________________
# conv3_2 (Conv2D)                (None, 54, 64, 128)  147584      conv3_1[0][0]
# __________________________________________________________________________________________________
# pool_3 (MaxPooling2D)           (None, 27, 32, 128)  0           conv3_2[0][0]
# __________________________________________________________________________________________________
# conv4_1 (Conv2D)                (None, 27, 32, 256)  295168      pool_3[0][0]
# __________________________________________________________________________________________________
# conv4_2 (Conv2D)                (None, 27, 32, 256)  590080      conv4_1[0][0]
# __________________________________________________________________________________________________
# upconv5_1 (UpSampling2D)        (None, 54, 64, 256)  0           conv4_2[0][0]
# __________________________________________________________________________________________________
# upconv5_2 (Conv2D)              (None, 54, 64, 128)  131200      upconv5_1[0][0]
# __________________________________________________________________________________________________
# concat_5 (Concatenate)          (None, 54, 64, 256)  0           upconv5_2[0][0]
#                                                                  conv3_2[0][0]
# __________________________________________________________________________________________________
# conv5_1 (Conv2D)                (None, 54, 64, 128)  295040      concat_5[0][0]
# __________________________________________________________________________________________________
# conv5_2 (Conv2D)                (None, 54, 64, 128)  147584      conv5_1[0][0]
# __________________________________________________________________________________________________
# upconv6_1 (UpSampling2D)        (None, 108, 128, 128 0           conv5_2[0][0]
# __________________________________________________________________________________________________
# upconv6_2 (Conv2D)              (None, 108, 128, 64) 32832       upconv6_1[0][0]
# __________________________________________________________________________________________________
# concat_6 (Concatenate)          (None, 108, 128, 128 0           upconv6_2[0][0]
#                                                                  conv2_2[0][0]
# __________________________________________________________________________________________________
# conv6_1 (Conv2D)                (None, 108, 128, 64) 73792       concat_6[0][0]
# __________________________________________________________________________________________________
# conv6_2 (Conv2D)                (None, 108, 128, 64) 36928       conv6_1[0][0]
# __________________________________________________________________________________________________
# upconv7_1 (UpSampling2D)        (None, 216, 256, 64) 0           conv6_2[0][0]
# __________________________________________________________________________________________________
# upconv7_2 (Conv2D)              (None, 216, 256, 32) 8224        upconv7_1[0][0]
# __________________________________________________________________________________________________
# concat_7 (Concatenate)          (None, 216, 256, 64) 0           upconv7_2[0][0]
#                                                                  conv1_2[0][0]
# __________________________________________________________________________________________________
# conv7_1 (Conv2D)                (None, 216, 256, 32) 18464       concat_7[0][0]
# __________________________________________________________________________________________________
# conv7_2 (Conv2D)                (None, 216, 256, 32) 9248        conv7_1[0][0]
# __________________________________________________________________________________________________
# conv8 (Conv2D)                  (None, 216, 256, 1)  33          conv7_2[0][0]
# ==================================================================================================
# Total params: 1,925,601
# Trainable params: 1,925,601
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def u_net_model(image_shape, keep_prob, num_of_classes):
  
  # Contracting Path
  
  input_image = Input(image_shape)
  
  conv1_1 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv1_1')(input_image)
  conv1_2 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv1_2')(conv1_1)
  
  pool_1 = MaxPooling2D(name = 'pool_1')(conv1_2)
  
  conv2_1 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv2_1')(pool_1)
  conv2_2 = Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv2_2')(conv2_1)
  
  pool_2 = MaxPooling2D(name = 'pool_2')(conv2_2)
  
  conv3_1 = Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv3_1')(pool_2)
  conv3_2 = Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv3_2')(conv3_1)
  
  pool_3 = MaxPooling2D(name = 'pool_3')(conv3_2)
  
  conv4_1 = Conv2D(filters = 512, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv4_1')(pool_3)
  conv4_2 = Conv2D(filters = 512, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv4_2')(conv4_1)
  drop_4 = Dropout(keep_prob, name = 'drop_4')(conv4_2)
  
  pool_4 = MaxPooling2D(name = 'pool_4')(drop_4)
  
  conv5_1 = Conv2D(filters = 1024, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv5_1')(pool_4)
  conv5_2 = Conv2D(filters = 1024, kernel_size = (3, 3), padding = 'same', activation = 'relu', name = 'conv5_2')(conv5_1)
  drop_5 = Dropout(keep_prob, name = 'drop_5')(conv5_2)
  
  
  
  # Expanding Path
  
  upconv6_1 = UpSampling2D(name = 'upconv6_1')(drop_5)
  upconv6_2 = Conv2D(filters = 512, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv6_2')(upconv6_1)
  cropped_4 = Cropping2D(((4, 4)), name = 'cropped_4')(drop_4)
  concat_6 = concatenate([upconv6_2, cropped_4], axis = 3, name = 'concat_6')
  
  conv6_1 = Conv2D(filters = 512, kernel_size = (3, 3), activation = 'relu', name = 'conv6_1')(concat_6)
  conv6_2 = Conv2D(filters = 512, kernel_size = (3, 3), activation = 'relu', name = 'conv6_2')(conv6_1)
  
  upconv7_1 = UpSampling2D(name = 'upconv7_1')(conv6_2)
  upconv7_2 = Conv2D(filters = 256, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv7_2')(upconv7_1)
  cropped_3 = Cropping2D((16, 16), name = 'cropped_3')(conv3_2)
  concat_7 = concatenate([upconv7_2, cropped_3], axis = 3, name = 'concat_7')
  
  conv7_1 = Conv2D(filters = 256, kernel_size = (3, 3), activation = 'relu', name = 'conv7_1')(concat_7)
  conv7_2 = Conv2D(filters = 256, kernel_size = (3, 3), activation = 'relu', name = 'conv7_2')(conv7_1)
  
  upconv8_1 = UpSampling2D(name = 'upconv8_1')(conv7_2)
  upconv8_2 = Conv2D(filters = 128, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv8_2')(upconv8_1)
  cropped_2 = Cropping2D((40, 40), name = 'cropped_2')(conv2_2)
  concat_8 = concatenate([upconv8_2, cropped_2], axis = 3, name = 'concat_8')
  
  conv8_1 = Conv2D(filters = 128, kernel_size = (3, 3), activation = 'relu', name = 'conv8_1')(concat_8)
  conv8_2 = Conv2D(filters = 128, kernel_size = (3, 3), activation = 'relu', name = 'conv8_2')(conv8_1)
  
  upconv9_1 = UpSampling2D(name = 'upconv9_1')(conv8_2)
  upconv9_2 = Conv2D(filters = 64, kernel_size = (2, 2), activation = 'relu', padding = 'same', name = 'upconv9_2')(upconv9_1)
  cropped_1 = Cropping2D((88, 88), name = 'cropped_1')(conv1_2)
  concat_9 = concatenate([upconv9_2, cropped_1], axis = 3, name = 'concat_9')
  
  conv9_1 = Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu', name = 'conv9_1')(concat_9)
  conv9_2 = Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu', name = 'conv9_2')(conv9_1)
  
  conv10 = Conv2D(filters = num_of_classes, kernel_size = (1, 1), activation = 'sigmoid', name = 'conv10')(conv9_2)
  
  
  model = Model(inputs = input_image, outputs = conv10, name = 'model')
  
  return model

# %%
# model = u_net_model(image_shape, keep_prob, num_of_classes)

# %%
# model.summary()

# %% [markdown]
# # COCO Dataset

# %%
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab

from glob import glob
from PIL import Image

# %%
# !pip install Cython
# !pip install pycocotools
# Out:
# Collecting Cython
#   Downloading https://files.pythonhosted.org/packages/19/8e/32b280abb0947a96cdbb8329fb2014851a21fc1d099009f946ea8a8202c3/Cython-0.28.5-cp36-cp36m-manylinux1_x86_64.whl (3.4MB)
#     100% |████████████████████████████████| 3.4MB 982kB/s
# Installing collected packages: Cython
# Successfully installed Cython-0.28.5
# Collecting pycocotools
#   Downloading https://files.pythonhosted.org/packages/96/84/9a07b1095fd8555ba3f3d519517c8743c2554a245f9476e5e39869f948d2/pycocotools-2.0.0.tar.gz (1.5MB)
#     100% |████████████████████████████████| 1.5MB 7.6MB/s
# Building wheels for collected packages: pycocotools
# done
#   Stored in directory: /root/.cache/pip/wheels/dc/e6/36/0e1ae88c868eb42d3f92181b1c9bbd0b217a7ec3da6bd62e55
# Successfully built pycocotools
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.0

# %%
from pycocotools.coco import COCO

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
cd /gdrive/My \Drive
# Out:
# /gdrive/My Drive

# %%
val_img_files = glob('cocoapi/images/' + '*.jp*g')
print(val_img_files[:3])
# Out:
# ['cocoapi/images/000000136355.jpg', 'cocoapi/images/000000077460.jpg', 'cocoapi/images/000000513484.jpg']

# %%
val_img_Ids = [int(id[-10:-4]) for id in val_img_files]
print(val_img_Ids[:3])
# Out:
# [136355, 77460, 513484]

# %%
dataDir='cocoapi'
dataType='val2017'
annFile='{}/annotations/instances_{}.json'.format(dataDir,dataType)
coco = COCO(annotation_file = annFile)
# Out:
# loading annotations into memory...
# Done (t=2.02s)
# creating index...
# index created!

# %%
cats = coco.loadCats(coco.getCatIds())

# %%
categories = []

for cat in cats:
  categories.append(cat['name'])

# %%
print(len(categories))
# Out:
# 80

# %%
cat_Ids = [cat['id'] for cat in cats]

# %%
def index_matching(cat_id, cat_Ids = cat_Ids, categories = categories):
  index = cat_Ids.index(cat_id)
  
  return categories[index], index, cat_id

# %%
def img_loader(imgIds, val_img_files):
  for img_path in val_img_files:
    if str(imgIds) in img_path:
      return img_path

# %%
def gt_maker(imgId, step, val_img_files = val_img_files, num_of_classes = num_of_classes, val_img_Ids = val_img_Ids):
  anns = coco.loadAnns(coco.getAnnIds(imgIds = [imgId]))
  annIds = coco.getAnnIds(imgIds = [imgId])
  img = image.img_to_array(Image.open(img_loader(imgId, val_img_files)).resize((256, 216)))
  
  
  if img.shape == (216, 256, 3):
  # mask = np.zeros(list(img.shape[:2]) + [num_of_classes])
    mask_1d = coco.annToMask(anns[0])
    
    for i in range(len(anns)):
      cat_id = anns[i]['category_id']
      _, index, _ = index_matching(cat_id)
      index -= 1
    
      mask_ann = coco.annToMask(anns[i])
    # mask_ann_re = image.img_to_array(Image.fromarray(mask_ann).resize((388, 388)))
    
      mask_1d += mask_ann * cat_id
    
    # mask_expand = np.expand_dims(mask_ann_re, axis = 2)
    
    # mask_pad = np.pad(mask_ann_re, pad_width = ((0, 0), (0, 0), (0, num_of_classes - 1)), mode = 'constant')
    
    # arridx = np.where(mask_pad == 1)
    # mask_pad[arridx] = 0
    # mask_pad[(arridx[0], arridx[1], arridx[2] + index)] = 1
    # mask += mask_pad
  
  
    mask_1d = image.img_to_array(Image.fromarray(mask_1d).resize((256, 216)))
    print("End : GT Image of Id", format(imgId, '^7'), "| shape = {0}".format(mask_1d.shape), "| step : [{0} / {1}]".format(step + 1, len(val_img_Ids)))
    
  return mask_1d, img

# %%
input_img = []
gt_img = []

for i, imgId in enumerate(val_img_Ids):
  try:
    gt, img = gt_maker(imgId, i)
    gt_img.append(gt)
    input_img.append(img)
  except Exception as ex:
    print(imgId, "error")
# Out:
# End : GT Image of Id 136355  | shape = (216, 256, 1) | step : [1 / 2327]
# End : GT Image of Id  77460  | shape = (216, 256, 1) | step : [2 / 2327]
# End : GT Image of Id 513484  | shape = (216, 256, 1) | step : [3 / 2327]
# End : GT Image of Id  47769  | shape = (216, 256, 1) | step : [4 / 2327]
# End : GT Image of Id 276285  | shape = (216, 256, 1) | step : [5 / 2327]
# End : GT Image of Id  17182  | shape = (216, 256, 1) | step : [6 / 2327]
# End : GT Image of Id 576052  | shape = (216, 256, 1) | step : [7 / 2327]
# End : GT Image of Id 159282  | shape = (216, 256, 1) | step : [8 / 2327]
# End : GT Image of Id 273711  | shape = (216, 256, 1) | step : [9 / 2327]
# End : GT Image of Id 574810  | shape = (216, 256, 1) | step : [10 / 2327]
# End : GT Image of Id 199395  | shape = (216, 256, 1) | step : [11 / 2327]
# End : GT Image of Id 527215  | shape = (216, 256, 1) | step : [12 / 2327]
# End : GT Image of Id 333069  | shape = (216, 256, 1) | step : [13 / 2327]
# End : GT Image of Id 401244  | shape = (216, 256, 1) | step : [14 / 2327]
# End : GT Image of Id 347370  | shape = (216, 256, 1) | step : [15 / 2327]
# End : GT Image of Id 525600  | shape = (216, 256, 1) | step : [16 / 2327]
# End : GT Image of Id  58705  | shape = (216, 256, 1) | step : [17 / 2327]
# End : GT Image of Id 508917  | shape = (216, 256, 1) | step : [18 / 2327]
# End : GT Image of Id 348243  | shape = (216, 256, 1) | step : [19 / 2327]
# End : GT Image of Id 343218  | shape = (216, 256, 1) | step : [20 / 2327]
# End : GT Image of Id 136715  | shape = (216, 256, 1) | step : [21 / 2327]
# End : GT Image of Id 498286  | shape = (216, 256, 1) | step : [22 / 2327]
# End : GT Image of Id 121242  | shape = (216, 256, 1) | step : [23 / 2327]
# End : GT Image of Id 370478  | shape = (216, 256, 1) | step : [24 / 2327]
# 98497 error
# End : GT Image of Id 216739  | shape = (216, 256, 1) | step : [26 / 2327]
# End : GT Image of Id 519569  | shape = (216, 256, 1) | step : [27 / 2327]
# End : GT Image of Id 189310  | shape = (216, 256, 1) | step : [28 / 2327]
# End : GT Image of Id 485802  | shape = (216, 256, 1) | step : [29 / 2327]
# End : GT Image of Id 113867  | shape = (216, 256, 1) | step : [30 / 2327]
# End : GT Image of Id 463842  | shape = (216, 256, 1) | step : [31 / 2327]
# End : GT Image of Id 515828  | shape = (216, 256, 1) | step : [32 / 2327]
# End : GT Image of Id 551804  | shape = (216, 256, 1) | step : [33 / 2327]
# End : GT Image of Id 166478  | shape = (216, 256, 1) | step : [34 / 2327]
# End : GT Image of Id 298697  | shape = (216, 256, 1) | step : [35 / 2327]
# End : GT Image of Id 532493  | shape = (216, 256, 1) | step : [36 / 2327]
# End : GT Image of Id 145781  | shape = (216, 256, 1) | step : [37 / 2327]
# End : GT Image of Id  60449  | shape = (216, 256, 1) | step : [38 / 2327]
# End : GT Image of Id 151857  | shape = (216, 256, 1) | step : [39 / 2327]
# End : GT Image of Id 425906  | shape = (216, 256, 1) | step : [40 / 2327]
# End : GT Image of Id 301376  | shape = (216, 256, 1) | step : [41 / 2327]
# End : GT Image of Id 234607  | shape = (216, 256, 1) | step : [42 / 2327]
# End : GT Image of Id 452084  | shape = (216, 256, 1) | step : [43 / 2327]
# End : GT Image of Id 455448  | shape = (216, 256, 1) | step : [44 / 2327]
# End : GT Image of Id  84477  | shape = (216, 256, 1) | step : [45 / 2327]
# End : GT Image of Id 204329  | shape = (216, 256, 1) | step : [46 / 2327]
# End : GT Image of Id 535156  | shape = (216, 256, 1) | step : [47 / 2327]
# End : GT Image of Id 467315  | shape = (216, 256, 1) | step : [48 / 2327]
# End : GT Image of Id 160012  | shape = (216, 256, 1) | step : [49 / 2327]
# 344611 error
# End : GT Image of Id 396526  | shape = (216, 256, 1) | step : [51 / 2327]
# End : GT Image of Id 460494  | shape = (216, 256, 1) | step : [52 / 2327]
# End : GT Image of Id 210915  | shape = (216, 256, 1) | step : [53 / 2327]
# End : GT Image of Id  51610  | shape = (216, 256, 1) | step : [54 / 2327]
# End : GT Image of Id 153782  | shape = (216, 256, 1) | step : [55 / 2327]
# End : GT Image of Id  1353   | shape = (216, 256, 1) | step : [56 / 2327]
# End : GT Image of Id 507473  | shape = (216, 256, 1) | step : [57 / 2327]
# End : GT Image of Id 403353  | shape = (216, 256, 1) | step : [58 / 2327]
# End : GT Image of Id 357060  | shape = (216, 256, 1) | step : [59 / 2327]
# End : GT Image of Id 375763  | shape = (216, 256, 1) | step : [60 / 2327]
# End : GT Image of Id 437514  | shape = (216, 256, 1) | step : [61 / 2327]
# End : GT Image of Id 183648  | shape = (216, 256, 1) | step : [62 / 2327]
# End : GT Image of Id 128675  | shape = (216, 256, 1) | step : [63 / 2327]
# End : GT Image of Id 335450  | shape = (216, 256, 1) | step : [64 / 2327]
# End : GT Image of Id 562243  | shape = (216, 256, 1) | step : [65 / 2327]
# End : GT Image of Id 252716  | shape = (216, 256, 1) | step : [66 / 2327]
# End : GT Image of Id 359540  | shape = (216, 256, 1) | step : [67 / 2327]
# End : GT Image of Id 235241  | shape = (216, 256, 1) | step : [68 / 2327]
# End : GT Image of Id  80274  | shape = (216, 256, 1) | step : [69 / 2327]
# End : GT Image of Id 577182  | shape = (216, 256, 1) | step : [70 / 2327]
# End : GT Image of Id 398377  | shape = (216, 256, 1) | step : [71 / 2327]
# End : GT Image of Id 554579  | shape = (216, 256, 1) | step : [72 / 2327]
# End : GT Image of Id 409475  | shape = (216, 256, 1) | step : [73 / 2327]
# End : GT Image of Id 553669  | shape = (216, 256, 1) | step : [74 / 2327]
# End : GT Image of Id 297084  | shape = (216, 256, 1) | step : [75 / 2327]
# End : GT Image of Id 117719  | shape = (216, 256, 1) | step : [76 / 2327]
# End : GT Image of Id 300039  | shape = (216, 256, 1) | step : [77 / 2327]
# End : GT Image of Id 144333  | shape = (216, 256, 1) | step : [78 / 2327]
# End : GT Image of Id 232538  | shape = (216, 256, 1) | step : [79 / 2327]
# End : GT Image of Id 154087  | shape = (216, 256, 1) | step : [80 / 2327]
# End : GT Image of Id 225670  | shape = (216, 256, 1) | step : [81 / 2327]
# End : GT Image of Id 229659  | shape = (216, 256, 1) | step : [82 / 2327]
# End : GT Image of Id 325347  | shape = (216, 256, 1) | step : [83 / 2327]
# End : GT Image of Id 437331  | shape = (216, 256, 1) | step : [84 / 2327]
# End : GT Image of Id 512476  | shape = (216, 256, 1) | step : [85 / 2327]
# End : GT Image of Id   785   | shape = (216, 256, 1) | step : [86 / 2327]
# End : GT Image of Id 439715  | shape = (216, 256, 1) | step : [87 / 2327]
# End : GT Image of Id 189820  | shape = (216, 256, 1) | step : [88 / 2327]
# End : GT Image of Id 523811  | shape = (216, 256, 1) | step : [89 / 2327]
# End : GT Image of Id 325527  | shape = (216, 256, 1) | step : [90 / 2327]
# End : GT Image of Id 427655  | shape = (216, 256, 1) | step : [91 / 2327]
# End : GT Image of Id 352618  | shape = (216, 256, 1) | step : [92 / 2327]
# End : GT Image of Id 400573  | shape = (216, 256, 1) | step : [93 / 2327]
# End : GT Image of Id 282046  | shape = (216, 256, 1) | step : [94 / 2327]
# End : GT Image of Id 363840  | shape = (216, 256, 1) | step : [95 / 2327]
# End : GT Image of Id 472375  | shape = (216, 256, 1) | step : [96 / 2327]
# End : GT Image of Id 482978  | shape = (216, 256, 1) | step : [97 / 2327]
# End : GT Image of Id  42296  | shape = (216, 256, 1) | step : [98 / 2327]
# End : GT Image of Id 357742  | shape = (216, 256, 1) | step : [99 / 2327]
# End : GT Image of Id 388927  | shape = (216, 256, 1) | step : [100 / 2327]
# End : GT Image of Id 568195  | shape = (216, 256, 1) | step : [101 / 2327]
# End : GT Image of Id 520910  | shape = (216, 256, 1) | step : [102 / 2327]
# End : GT Image of Id  81061  | shape = (216, 256, 1) | step : [103 / 2327]
# End : GT Image of Id 468954  | shape = (216, 256, 1) | step : [104 / 2327]
# End : GT Image of Id 563470  | shape = (216, 256, 1) | step : [105 / 2327]
# End : GT Image of Id 300659  | shape = (216, 256, 1) | step : [106 / 2327]
# End : GT Image of Id 357748  | shape = (216, 256, 1) | step : [107 / 2327]
# End : GT Image of Id  3553   | shape = (216, 256, 1) | step : [108 / 2327]
# End : GT Image of Id 293044  | shape = (216, 256, 1) | step : [109 / 2327]
# End : GT Image of Id 269942  | shape = (216, 256, 1) | step : [110 / 2327]
# End : GT Image of Id  45550  | shape = (216, 256, 1) | step : [111 / 2327]
# End : GT Image of Id 440171  | shape = (216, 256, 1) | step : [112 / 2327]
# End : GT Image of Id 451693  | shape = (216, 256, 1) | step : [113 / 2327]
# End : GT Image of Id  79188  | shape = (216, 256, 1) | step : [114 / 2327]
# End : GT Image of Id 220732  | shape = (216, 256, 1) | step : [115 / 2327]
# End : GT Image of Id 136915  | shape = (216, 256, 1) | step : [116 / 2327]
# End : GT Image of Id 193162  | shape = (216, 256, 1) | step : [117 / 2327]
# End : GT Image of Id 267191  | shape = (216, 256, 1) | step : [118 / 2327]
# End : GT Image of Id 136334  | shape = (216, 256, 1) | step : [119 / 2327]
# End : GT Image of Id 434230  | shape = (216, 256, 1) | step : [120 / 2327]
# End : GT Image of Id 469828  | shape = (216, 256, 1) | step : [121 / 2327]
# End : GT Image of Id 462904  | shape = (216, 256, 1) | step : [122 / 2327]
# End : GT Image of Id 338532  | shape = (216, 256, 1) | step : [123 / 2327]
# End : GT Image of Id 203488  | shape = (216, 256, 1) | step : [124 / 2327]
# End : GT Image of Id 176901  | shape = (216, 256, 1) | step : [125 / 2327]
# End : GT Image of Id 111207  | shape = (216, 256, 1) | step : [126 / 2327]
# End : GT Image of Id 382696  | shape = (216, 256, 1) | step : [127 / 2327]
# End : GT Image of Id 553094  | shape = (216, 256, 1) | step : [128 / 2327]
# End : GT Image of Id 531036  | shape = (216, 256, 1) | step : [129 / 2327]
# End : GT Image of Id 509824  | shape = (216, 256, 1) | step : [130 / 2327]
# End : GT Image of Id 551439  | shape = (216, 256, 1) | step : [131 / 2327]
# End : GT Image of Id  29596  | shape = (216, 256, 1) | step : [132 / 2327]
# End : GT Image of Id  6614   | shape = (216, 256, 1) | step : [133 / 2327]
# End : GT Image of Id  6818   | shape = (216, 256, 1) | step : [134 / 2327]
# End : GT Image of Id 394206  | shape = (216, 256, 1) | step : [135 / 2327]
# End : GT Image of Id 421455  | shape = (216, 256, 1) | step : [136 / 2327]
# End : GT Image of Id  92177  | shape = (216, 256, 1) | step : [137 / 2327]
# End : GT Image of Id 273712  | shape = (216, 256, 1) | step : [138 / 2327]
# End : GT Image of Id  67896  | shape = (216, 256, 1) | step : [139 / 2327]
# End : GT Image of Id 264335  | shape = (216, 256, 1) | step : [140 / 2327]
# End : GT Image of Id 409542  | shape = (216, 256, 1) | step : [141 / 2327]
# End : GT Image of Id 286994  | shape = (216, 256, 1) | step : [142 / 2327]
# End : GT Image of Id 316054  | shape = (216, 256, 1) | step : [143 / 2327]
# End : GT Image of Id 366225  | shape = (216, 256, 1) | step : [144 / 2327]
# End : GT Image of Id 277197  | shape = (216, 256, 1) | step : [145 / 2327]
# End : GT Image of Id 440336  | shape = (216, 256, 1) | step : [146 / 2327]
# End : GT Image of Id 280930  | shape = (216, 256, 1) | step : [147 / 2327]
# End : GT Image of Id  68078  | shape = (216, 256, 1) | step : [148 / 2327]
# End : GT Image of Id 543043  | shape = (216, 256, 1) | step : [149 / 2327]
# End : GT Image of Id  40036  | shape = (216, 256, 1) | step : [150 / 2327]
# End : GT Image of Id 507015  | shape = (216, 256, 1) | step : [151 / 2327]
# End : GT Image of Id 396729  | shape = (216, 256, 1) | step : [152 / 2327]
# End : GT Image of Id 436883  | shape = (216, 256, 1) | step : [153 / 2327]
# End : GT Image of Id 248334  | shape = (216, 256, 1) | step : [154 / 2327]
# End : GT Image of Id  39769  | shape = (216, 256, 1) | step : [155 / 2327]
# End : GT Image of Id 222735  | shape = (216, 256, 1) | step : [156 / 2327]
# End : GT Image of Id 500478  | shape = (216, 256, 1) | step : [157 / 2327]
# End : GT Image of Id  20059  | shape = (216, 256, 1) | step : [158 / 2327]
# End : GT Image of Id 252776  | shape = (216, 256, 1) | step : [159 / 2327]
# End : GT Image of Id 193674  | shape = (216, 256, 1) | step : [160 / 2327]
# End : GT Image of Id 412531  | shape = (216, 256, 1) | step : [161 / 2327]
# End : GT Image of Id 579307  | shape = (216, 256, 1) | step : [162 / 2327]
# End : GT Image of Id 125405  | shape = (216, 256, 1) | step : [163 / 2327]
# End : GT Image of Id 129492  | shape = (216, 256, 1) | step : [164 / 2327]
# End : GT Image of Id 166166  | shape = (216, 256, 1) | step : [165 / 2327]
# End : GT Image of Id  16439  | shape = (216, 256, 1) | step : [166 / 2327]
# End : GT Image of Id  87742  | shape = (216, 256, 1) | step : [167 / 2327]
# End : GT Image of Id 293324  | shape = (216, 256, 1) | step : [168 / 2327]
# End : GT Image of Id 489014  | shape = (216, 256, 1) | step : [169 / 2327]
# End : GT Image of Id 167067  | shape = (216, 256, 1) | step : [170 / 2327]
# End : GT Image of Id 283113  | shape = (216, 256, 1) | step : [171 / 2327]
# End : GT Image of Id 320554  | shape = (216, 256, 1) | step : [172 / 2327]
# End : GT Image of Id 513041  | shape = (216, 256, 1) | step : [173 / 2327]
# End : GT Image of Id 345385  | shape = (216, 256, 1) | step : [174 / 2327]
# End : GT Image of Id 315450  | shape = (216, 256, 1) | step : [175 / 2327]
# End : GT Image of Id 351810  | shape = (216, 256, 1) | step : [176 / 2327]
# End : GT Image of Id  41990  | shape = (216, 256, 1) | step : [177 / 2327]
# End : GT Image of Id 397303  | shape = (216, 256, 1) | step : [178 / 2327]
# End : GT Image of Id 551780  | shape = (216, 256, 1) | step : [179 / 2327]
# End : GT Image of Id 350054  | shape = (216, 256, 1) | step : [180 / 2327]
# End : GT Image of Id 394275  | shape = (216, 256, 1) | step : [181 / 2327]
# End : GT Image of Id 183049  | shape = (216, 256, 1) | step : [182 / 2327]
# End : GT Image of Id 344059  | shape = (216, 256, 1) | step : [183 / 2327]
# End : GT Image of Id 514979  | shape = (216, 256, 1) | step : [184 / 2327]
# End : GT Image of Id 100624  | shape = (216, 256, 1) | step : [185 / 2327]
# 374727 error
# End : GT Image of Id 119233  | shape = (216, 256, 1) | step : [187 / 2327]
# End : GT Image of Id 147745  | shape = (216, 256, 1) | step : [188 / 2327]
# End : GT Image of Id  92091  | shape = (216, 256, 1) | step : [189 / 2327]
# End : GT Image of Id  5586   | shape = (216, 256, 1) | step : [190 / 2327]
# End : GT Image of Id 341058  | shape = (216, 256, 1) | step : [191 / 2327]
# End : GT Image of Id 451144  | shape = (216, 256, 1) | step : [192 / 2327]
# End : GT Image of Id  29675  | shape = (216, 256, 1) | step : [193 / 2327]
# End : GT Image of Id 326627  | shape = (216, 256, 1) | step : [194 / 2327]
# End : GT Image of Id 441553  | shape = (216, 256, 1) | step : [195 / 2327]
# End : GT Image of Id  36936  | shape = (216, 256, 1) | step : [196 / 2327]
# End : GT Image of Id 289741  | shape = (216, 256, 1) | step : [197 / 2327]
# End : GT Image of Id 130579  | shape = (216, 256, 1) | step : [198 / 2327]
# End : GT Image of Id 504074  | shape = (216, 256, 1) | step : [199 / 2327]
# End : GT Image of Id 310862  | shape = (216, 256, 1) | step : [200 / 2327]
# End : GT Image of Id 117645  | shape = (216, 256, 1) | step : [201 / 2327]
# End : GT Image of Id 475484  | shape = (216, 256, 1) | step : [202 / 2327]
# End : GT Image of Id 533206  | shape = (216, 256, 1) | step : [203 / 2327]
# End : GT Image of Id 213830  | shape = (216, 256, 1) | step : [204 / 2327]
# End : GT Image of Id 319721  | shape = (216, 256, 1) | step : [205 / 2327]
# End : GT Image of Id 442993  | shape = (216, 256, 1) | step : [206 / 2327]
# End : GT Image of Id 410612  | shape = (216, 256, 1) | step : [207 / 2327]
# End : GT Image of Id 153527  | shape = (216, 256, 1) | step : [208 / 2327]
# End : GT Image of Id 281409  | shape = (216, 256, 1) | step : [209 / 2327]
# End : GT Image of Id  38070  | shape = (216, 256, 1) | step : [210 / 2327]
# End : GT Image of Id 445602  | shape = (216, 256, 1) | step : [211 / 2327]
# End : GT Image of Id 446117  | shape = (216, 256, 1) | step : [212 / 2327]
# End : GT Image of Id 172330  | shape = (216, 256, 1) | step : [213 / 2327]
# End : GT Image of Id 267537  | shape = (216, 256, 1) | step : [214 / 2327]
# End : GT Image of Id  7784   | shape = (216, 256, 1) | step : [215 / 2327]
# End : GT Image of Id 242060  | shape = (216, 256, 1) | step : [216 / 2327]
# End : GT Image of Id 467848  | shape = (216, 256, 1) | step : [217 / 2327]
# End : GT Image of Id 435205  | shape = (216, 256, 1) | step : [218 / 2327]
# End : GT Image of Id 520659  | shape = (216, 256, 1) | step : [219 / 2327]
# End : GT Image of Id 569825  | shape = (216, 256, 1) | step : [220 / 2327]
# End : GT Image of Id 143556  | shape = (216, 256, 1) | step : [221 / 2327]
# End : GT Image of Id 340451  | shape = (216, 256, 1) | step : [222 / 2327]
# End : GT Image of Id 122166  | shape = (216, 256, 1) | step : [223 / 2327]
# End : GT Image of Id 419098  | shape = (216, 256, 1) | step : [224 / 2327]
# End : GT Image of Id  46463  | shape = (216, 256, 1) | step : [225 / 2327]
# End : GT Image of Id 226592  | shape = (216, 256, 1) | step : [226 / 2327]
# End : GT Image of Id 297830  | shape = (216, 256, 1) | step : [227 / 2327]
# End : GT Image of Id 551794  | shape = (216, 256, 1) | step : [228 / 2327]
# End : GT Image of Id 345941  | shape = (216, 256, 1) | step : [229 / 2327]
# End : GT Image of Id 468332  | shape = (216, 256, 1) | step : [230 / 2327]
# End : GT Image of Id 491366  | shape = (216, 256, 1) | step : [231 / 2327]
# End : GT Image of Id 346707  | shape = (216, 256, 1) | step : [232 / 2327]
# End : GT Image of Id 401862  | shape = (216, 256, 1) | step : [233 / 2327]
# End : GT Image of Id 471789  | shape = (216, 256, 1) | step : [234 / 2327]
# End : GT Image of Id  57149  | shape = (216, 256, 1) | step : [235 / 2327]
# End : GT Image of Id 154718  | shape = (216, 256, 1) | step : [236 / 2327]
# End : GT Image of Id 400082  | shape = (216, 256, 1) | step : [237 / 2327]
# End : GT Image of Id 122606  | shape = (216, 256, 1) | step : [238 / 2327]
# End : GT Image of Id 509451  | shape = (216, 256, 1) | step : [239 / 2327]
# End : GT Image of Id 415194  | shape = (216, 256, 1) | step : [240 / 2327]
# End : GT Image of Id 509403  | shape = (216, 256, 1) | step : [241 / 2327]
# End : GT Image of Id 128654  | shape = (216, 256, 1) | step : [242 / 2327]
# End : GT Image of Id 386912  | shape = (216, 256, 1) | step : [243 / 2327]
# End : GT Image of Id 217948  | shape = (216, 256, 1) | step : [244 / 2327]
# 141671 error
# End : GT Image of Id  1675   | shape = (216, 256, 1) | step : [246 / 2327]
# End : GT Image of Id  80949  | shape = (216, 256, 1) | step : [247 / 2327]
# End : GT Image of Id 210299  | shape = (216, 256, 1) | step : [248 / 2327]
# End : GT Image of Id 281414  | shape = (216, 256, 1) | step : [249 / 2327]
# End : GT Image of Id 480212  | shape = (216, 256, 1) | step : [250 / 2327]
# End : GT Image of Id 568213  | shape = (216, 256, 1) | step : [251 / 2327]
# End : GT Image of Id 419201  | shape = (216, 256, 1) | step : [252 / 2327]
# End : GT Image of Id 361551  | shape = (216, 256, 1) | step : [253 / 2327]
# End : GT Image of Id  44590  | shape = (216, 256, 1) | step : [254 / 2327]
# End : GT Image of Id  52413  | shape = (216, 256, 1) | step : [255 / 2327]
# End : GT Image of Id 186873  | shape = (216, 256, 1) | step : [256 / 2327]
# End : GT Image of Id 238039  | shape = (216, 256, 1) | step : [257 / 2327]
# End : GT Image of Id 314251  | shape = (216, 256, 1) | step : [258 / 2327]
# End : GT Image of Id  15278  | shape = (216, 256, 1) | step : [259 / 2327]
# End : GT Image of Id 356125  | shape = (216, 256, 1) | step : [260 / 2327]
# End : GT Image of Id 107554  | shape = (216, 256, 1) | step : [261 / 2327]
# End : GT Image of Id 185599  | shape = (216, 256, 1) | step : [262 / 2327]
# End : GT Image of Id 305309  | shape = (216, 256, 1) | step : [263 / 2327]
# End : GT Image of Id 494863  | shape = (216, 256, 1) | step : [264 / 2327]
# End : GT Image of Id 286182  | shape = (216, 256, 1) | step : [265 / 2327]
# End : GT Image of Id  33854  | shape = (216, 256, 1) | step : [266 / 2327]
# End : GT Image of Id 580757  | shape = (216, 256, 1) | step : [267 / 2327]
# End : GT Image of Id 528578  | shape = (216, 256, 1) | step : [268 / 2327]
# End : GT Image of Id 223130  | shape = (216, 256, 1) | step : [269 / 2327]
# End : GT Image of Id  76731  | shape = (216, 256, 1) | step : [270 / 2327]
# End : GT Image of Id 577149  | shape = (216, 256, 1) | step : [271 / 2327]
# End : GT Image of Id 288685  | shape = (216, 256, 1) | step : [272 / 2327]
# End : GT Image of Id 535253  | shape = (216, 256, 1) | step : [273 / 2327]
# End : GT Image of Id  73533  | shape = (216, 256, 1) | step : [274 / 2327]
# End : GT Image of Id 294162  | shape = (216, 256, 1) | step : [275 / 2327]
# End : GT Image of Id 136466  | shape = (216, 256, 1) | step : [276 / 2327]
# End : GT Image of Id 356505  | shape = (216, 256, 1) | step : [277 / 2327]
# End : GT Image of Id 284743  | shape = (216, 256, 1) | step : [278 / 2327]
# End : GT Image of Id 459467  | shape = (216, 256, 1) | step : [279 / 2327]
# End : GT Image of Id 492758  | shape = (216, 256, 1) | step : [280 / 2327]
# End : GT Image of Id 196754  | shape = (216, 256, 1) | step : [281 / 2327]
# End : GT Image of Id 442463  | shape = (216, 256, 1) | step : [282 / 2327]
# End : GT Image of Id 453001  | shape = (216, 256, 1) | step : [283 / 2327]
# End : GT Image of Id 526256  | shape = (216, 256, 1) | step : [284 / 2327]
# End : GT Image of Id 512657  | shape = (216, 256, 1) | step : [285 / 2327]
# End : GT Image of Id 148620  | shape = (216, 256, 1) | step : [286 / 2327]
# End : GT Image of Id 530457  | shape = (216, 256, 1) | step : [287 / 2327]
# End : GT Image of Id 343561  | shape = (216, 256, 1) | step : [288 / 2327]
# End : GT Image of Id 293245  | shape = (216, 256, 1) | step : [289 / 2327]
# End : GT Image of Id 285349  | shape = (216, 256, 1) | step : [290 / 2327]
# End : GT Image of Id 116362  | shape = (216, 256, 1) | step : [291 / 2327]
# End : GT Image of Id 290843  | shape = (216, 256, 1) | step : [292 / 2327]
# End : GT Image of Id 194875  | shape = (216, 256, 1) | step : [293 / 2327]
# End : GT Image of Id 547336  | shape = (216, 256, 1) | step : [294 / 2327]
# End : GT Image of Id 163562  | shape = (216, 256, 1) | step : [295 / 2327]
# End : GT Image of Id 517069  | shape = (216, 256, 1) | step : [296 / 2327]
# End : GT Image of Id 448256  | shape = (216, 256, 1) | step : [297 / 2327]
# End : GT Image of Id 128598  | shape = (216, 256, 1) | step : [298 / 2327]
# End : GT Image of Id 237928  | shape = (216, 256, 1) | step : [299 / 2327]
# End : GT Image of Id 403565  | shape = (216, 256, 1) | step : [300 / 2327]
# End : GT Image of Id 205834  | shape = (216, 256, 1) | step : [301 / 2327]
# End : GT Image of Id 490413  | shape = (216, 256, 1) | step : [302 / 2327]
# End : GT Image of Id 117744  | shape = (216, 256, 1) | step : [303 / 2327]
# End : GT Image of Id 221017  | shape = (216, 256, 1) | step : [304 / 2327]
# End : GT Image of Id 566282  | shape = (216, 256, 1) | step : [305 / 2327]
# End : GT Image of Id 313454  | shape = (216, 256, 1) | step : [306 / 2327]
# End : GT Image of Id 125211  | shape = (216, 256, 1) | step : [307 / 2327]
# End : GT Image of Id 482275  | shape = (216, 256, 1) | step : [308 / 2327]
# End : GT Image of Id 297681  | shape = (216, 256, 1) | step : [309 / 2327]
# End : GT Image of Id 537270  | shape = (216, 256, 1) | step : [310 / 2327]
# End : GT Image of Id 131431  | shape = (216, 256, 1) | step : [311 / 2327]
# End : GT Image of Id  73118  | shape = (216, 256, 1) | step : [312 / 2327]
# End : GT Image of Id 290592  | shape = (216, 256, 1) | step : [313 / 2327]
# End : GT Image of Id 194746  | shape = (216, 256, 1) | step : [314 / 2327]
# End : GT Image of Id 131444  | shape = (216, 256, 1) | step : [315 / 2327]
# End : GT Image of Id 357501  | shape = (216, 256, 1) | step : [316 / 2327]
# End : GT Image of Id 378515  | shape = (216, 256, 1) | step : [317 / 2327]
# End : GT Image of Id  5477   | shape = (216, 256, 1) | step : [318 / 2327]
# End : GT Image of Id 334521  | shape = (216, 256, 1) | step : [319 / 2327]
# End : GT Image of Id 153299  | shape = (216, 256, 1) | step : [320 / 2327]
# End : GT Image of Id 430286  | shape = (216, 256, 1) | step : [321 / 2327]
# End : GT Image of Id 144798  | shape = (216, 256, 1) | step : [322 / 2327]
# End : GT Image of Id 190753  | shape = (216, 256, 1) | step : [323 / 2327]
# End : GT Image of Id  31217  | shape = (216, 256, 1) | step : [324 / 2327]
# End : GT Image of Id 153529  | shape = (216, 256, 1) | step : [325 / 2327]
# End : GT Image of Id 430073  | shape = (216, 256, 1) | step : [326 / 2327]
# End : GT Image of Id 410510  | shape = (216, 256, 1) | step : [327 / 2327]
# End : GT Image of Id 406570  | shape = (216, 256, 1) | step : [328 / 2327]
# End : GT Image of Id 470773  | shape = (216, 256, 1) | step : [329 / 2327]
# End : GT Image of Id 135670  | shape = (216, 256, 1) | step : [330 / 2327]
# End : GT Image of Id 288882  | shape = (216, 256, 1) | step : [331 / 2327]
# End : GT Image of Id  89880  | shape = (216, 256, 1) | step : [332 / 2327]
# End : GT Image of Id  59920  | shape = (216, 256, 1) | step : [333 / 2327]
# End : GT Image of Id 559707  | shape = (216, 256, 1) | step : [334 / 2327]
# End : GT Image of Id 352760  | shape = (216, 256, 1) | step : [335 / 2327]
# End : GT Image of Id 235778  | shape = (216, 256, 1) | step : [336 / 2327]
# End : GT Image of Id 187745  | shape = (216, 256, 1) | step : [337 / 2327]
# End : GT Image of Id 327617  | shape = (216, 256, 1) | step : [338 / 2327]
# End : GT Image of Id 427649  | shape = (216, 256, 1) | step : [339 / 2327]
# End : GT Image of Id 323355  | shape = (216, 256, 1) | step : [340 / 2327]
# End : GT Image of Id  5001   | shape = (216, 256, 1) | step : [341 / 2327]
# End : GT Image of Id  18770  | shape = (216, 256, 1) | step : [342 / 2327]
# End : GT Image of Id 354753  | shape = (216, 256, 1) | step : [343 / 2327]
# End : GT Image of Id 315001  | shape = (216, 256, 1) | step : [344 / 2327]
# End : GT Image of Id 110282  | shape = (216, 256, 1) | step : [345 / 2327]
# End : GT Image of Id 386210  | shape = (216, 256, 1) | step : [346 / 2327]
# End : GT Image of Id 362682  | shape = (216, 256, 1) | step : [347 / 2327]
# End : GT Image of Id 447917  | shape = (216, 256, 1) | step : [348 / 2327]
# End : GT Image of Id 414385  | shape = (216, 256, 1) | step : [349 / 2327]
# End : GT Image of Id 430875  | shape = (216, 256, 1) | step : [350 / 2327]
# End : GT Image of Id  98716  | shape = (216, 256, 1) | step : [351 / 2327]
# End : GT Image of Id 135872  | shape = (216, 256, 1) | step : [352 / 2327]
# End : GT Image of Id 402992  | shape = (216, 256, 1) | step : [353 / 2327]
# End : GT Image of Id 491497  | shape = (216, 256, 1) | step : [354 / 2327]
# End : GT Image of Id 431896  | shape = (216, 256, 1) | step : [355 / 2327]
# End : GT Image of Id  6723   | shape = (216, 256, 1) | step : [356 / 2327]
# End : GT Image of Id 485424  | shape = (216, 256, 1) | step : [357 / 2327]
# End : GT Image of Id  45090  | shape = (216, 256, 1) | step : [358 / 2327]
# End : GT Image of Id 489339  | shape = (216, 256, 1) | step : [359 / 2327]
# End : GT Image of Id 105912  | shape = (216, 256, 1) | step : [360 / 2327]
# End : GT Image of Id 291861  | shape = (216, 256, 1) | step : [361 / 2327]
# End : GT Image of Id 300913  | shape = (216, 256, 1) | step : [362 / 2327]
# End : GT Image of Id 430871  | shape = (216, 256, 1) | step : [363 / 2327]
# End : GT Image of Id 530146  | shape = (216, 256, 1) | step : [364 / 2327]
# End : GT Image of Id 347174  | shape = (216, 256, 1) | step : [365 / 2327]
# End : GT Image of Id 376625  | shape = (216, 256, 1) | step : [366 / 2327]
# End : GT Image of Id 402473  | shape = (216, 256, 1) | step : [367 / 2327]
# End : GT Image of Id  21167  | shape = (216, 256, 1) | step : [368 / 2327]
# End : GT Image of Id 308466  | shape = (216, 256, 1) | step : [369 / 2327]
# End : GT Image of Id 166747  | shape = (216, 256, 1) | step : [370 / 2327]
# End : GT Image of Id 411774  | shape = (216, 256, 1) | step : [371 / 2327]
# End : GT Image of Id 545958  | shape = (216, 256, 1) | step : [372 / 2327]
# End : GT Image of Id  82696  | shape = (216, 256, 1) | step : [373 / 2327]
# End : GT Image of Id 307074  | shape = (216, 256, 1) | step : [374 / 2327]
# End : GT Image of Id 468245  | shape = (216, 256, 1) | step : [375 / 2327]
# End : GT Image of Id  7795   | shape = (216, 256, 1) | step : [376 / 2327]
# End : GT Image of Id  90155  | shape = (216, 256, 1) | step : [377 / 2327]
# End : GT Image of Id 147518  | shape = (216, 256, 1) | step : [378 / 2327]
# End : GT Image of Id 455981  | shape = (216, 256, 1) | step : [379 / 2327]
# End : GT Image of Id 146358  | shape = (216, 256, 1) | step : [380 / 2327]
# End : GT Image of Id 295231  | shape = (216, 256, 1) | step : [381 / 2327]
# End : GT Image of Id 226984  | shape = (216, 256, 1) | step : [382 / 2327]
# End : GT Image of Id 372307  | shape = (216, 256, 1) | step : [383 / 2327]
# End : GT Image of Id 126226  | shape = (216, 256, 1) | step : [384 / 2327]
# End : GT Image of Id 578792  | shape = (216, 256, 1) | step : [385 / 2327]
# End : GT Image of Id 413247  | shape = (216, 256, 1) | step : [386 / 2327]
# End : GT Image of Id 402783  | shape = (216, 256, 1) | step : [387 / 2327]
# End : GT Image of Id 382030  | shape = (216, 256, 1) | step : [388 / 2327]
# End : GT Image of Id 361730  | shape = (216, 256, 1) | step : [389 / 2327]
# End : GT Image of Id  38829  | shape = (216, 256, 1) | step : [390 / 2327]
# End : GT Image of Id  22705  | shape = (216, 256, 1) | step : [391 / 2327]
# End : GT Image of Id 112110  | shape = (216, 256, 1) | step : [392 / 2327]
# End : GT Image of Id 439426  | shape = (216, 256, 1) | step : [393 / 2327]
# End : GT Image of Id 288762  | shape = (216, 256, 1) | step : [394 / 2327]
# End : GT Image of Id 541634  | shape = (216, 256, 1) | step : [395 / 2327]
# End : GT Image of Id  22396  | shape = (216, 256, 1) | step : [396 / 2327]
# End : GT Image of Id 407960  | shape = (216, 256, 1) | step : [397 / 2327]
# End : GT Image of Id 101068  | shape = (216, 256, 1) | step : [398 / 2327]
# End : GT Image of Id 148730  | shape = (216, 256, 1) | step : [399 / 2327]
# End : GT Image of Id 314034  | shape = (216, 256, 1) | step : [400 / 2327]
# End : GT Image of Id 282912  | shape = (216, 256, 1) | step : [401 / 2327]
# End : GT Image of Id 277020  | shape = (216, 256, 1) | step : [402 / 2327]
# End : GT Image of Id  45472  | shape = (216, 256, 1) | step : [403 / 2327]
# End : GT Image of Id 459437  | shape = (216, 256, 1) | step : [404 / 2327]
# End : GT Image of Id 470173  | shape = (216, 256, 1) | step : [405 / 2327]
# End : GT Image of Id  16010  | shape = (216, 256, 1) | step : [406 / 2327]
# End : GT Image of Id  39405  | shape = (216, 256, 1) | step : [407 / 2327]
# End : GT Image of Id 470952  | shape = (216, 256, 1) | step : [408 / 2327]
# End : GT Image of Id 552371  | shape = (216, 256, 1) | step : [409 / 2327]
# End : GT Image of Id 255718  | shape = (216, 256, 1) | step : [410 / 2327]
# End : GT Image of Id 122927  | shape = (216, 256, 1) | step : [411 / 2327]
# End : GT Image of Id  99182  | shape = (216, 256, 1) | step : [412 / 2327]
# End : GT Image of Id 185409  | shape = (216, 256, 1) | step : [413 / 2327]
# End : GT Image of Id 227482  | shape = (216, 256, 1) | step : [414 / 2327]
# End : GT Image of Id 579635  | shape = (216, 256, 1) | step : [415 / 2327]
# End : GT Image of Id 128051  | shape = (216, 256, 1) | step : [416 / 2327]
# End : GT Image of Id 331317  | shape = (216, 256, 1) | step : [417 / 2327]
# End : GT Image of Id 297353  | shape = (216, 256, 1) | step : [418 / 2327]
# End : GT Image of Id 410712  | shape = (216, 256, 1) | step : [419 / 2327]
# End : GT Image of Id 283520  | shape = (216, 256, 1) | step : [420 / 2327]
# End : GT Image of Id 118515  | shape = (216, 256, 1) | step : [421 / 2327]
# 353180 error
# End : GT Image of Id 230450  | shape = (216, 256, 1) | step : [423 / 2327]
# End : GT Image of Id 530820  | shape = (216, 256, 1) | step : [424 / 2327]
# End : GT Image of Id  60090  | shape = (216, 256, 1) | step : [425 / 2327]
# End : GT Image of Id 404805  | shape = (216, 256, 1) | step : [426 / 2327]
# End : GT Image of Id 565153  | shape = (216, 256, 1) | step : [427 / 2327]
# End : GT Image of Id 305609  | shape = (216, 256, 1) | step : [428 / 2327]
# End : GT Image of Id 221693  | shape = (216, 256, 1) | step : [429 / 2327]
# End : GT Image of Id 390902  | shape = (216, 256, 1) | step : [430 / 2327]
# End : GT Image of Id 196141  | shape = (216, 256, 1) | step : [431 / 2327]
# End : GT Image of Id  13659  | shape = (216, 256, 1) | step : [432 / 2327]
# End : GT Image of Id 354829  | shape = (216, 256, 1) | step : [433 / 2327]
# End : GT Image of Id 483667  | shape = (216, 256, 1) | step : [434 / 2327]
# End : GT Image of Id 414340  | shape = (216, 256, 1) | step : [435 / 2327]
# End : GT Image of Id 465806  | shape = (216, 256, 1) | step : [436 / 2327]
# End : GT Image of Id 522940  | shape = (216, 256, 1) | step : [437 / 2327]
# End : GT Image of Id 206411  | shape = (216, 256, 1) | step : [438 / 2327]
# End : GT Image of Id 258793  | shape = (216, 256, 1) | step : [439 / 2327]
# End : GT Image of Id 189226  | shape = (216, 256, 1) | step : [440 / 2327]
# End : GT Image of Id 551815  | shape = (216, 256, 1) | step : [441 / 2327]
# End : GT Image of Id 283037  | shape = (216, 256, 1) | step : [442 / 2327]
# End : GT Image of Id 409211  | shape = (216, 256, 1) | step : [443 / 2327]
# End : GT Image of Id 438269  | shape = (216, 256, 1) | step : [444 / 2327]
# End : GT Image of Id 563604  | shape = (216, 256, 1) | step : [445 / 2327]
# End : GT Image of Id 499622  | shape = (216, 256, 1) | step : [446 / 2327]
# End : GT Image of Id 532761  | shape = (216, 256, 1) | step : [447 / 2327]
# End : GT Image of Id 432085  | shape = (216, 256, 1) | step : [448 / 2327]
# End : GT Image of Id 226802  | shape = (216, 256, 1) | step : [449 / 2327]
# End : GT Image of Id 520324  | shape = (216, 256, 1) | step : [450 / 2327]
# End : GT Image of Id 463647  | shape = (216, 256, 1) | step : [451 / 2327]
# End : GT Image of Id 172856  | shape = (216, 256, 1) | step : [452 / 2327]
# End : GT Image of Id  94852  | shape = (216, 256, 1) | step : [453 / 2327]
# End : GT Image of Id 133778  | shape = (216, 256, 1) | step : [454 / 2327]
# End : GT Image of Id 210273  | shape = (216, 256, 1) | step : [455 / 2327]
# End : GT Image of Id 143572  | shape = (216, 256, 1) | step : [456 / 2327]
# End : GT Image of Id 244496  | shape = (216, 256, 1) | step : [457 / 2327]
# End : GT Image of Id 565607  | shape = (216, 256, 1) | step : [458 / 2327]
# End : GT Image of Id 170116  | shape = (216, 256, 1) | step : [459 / 2327]
# End : GT Image of Id  36539  | shape = (216, 256, 1) | step : [460 / 2327]
# End : GT Image of Id 343496  | shape = (216, 256, 1) | step : [461 / 2327]
# End : GT Image of Id 162858  | shape = (216, 256, 1) | step : [462 / 2327]
# End : GT Image of Id 329323  | shape = (216, 256, 1) | step : [463 / 2327]
# End : GT Image of Id 474881  | shape = (216, 256, 1) | step : [464 / 2327]
# End : GT Image of Id  76547  | shape = (216, 256, 1) | step : [465 / 2327]
# End : GT Image of Id 141597  | shape = (216, 256, 1) | step : [466 / 2327]
# End : GT Image of Id 172571  | shape = (216, 256, 1) | step : [467 / 2327]
# End : GT Image of Id 232649  | shape = (216, 256, 1) | step : [468 / 2327]
# End : GT Image of Id 157213  | shape = (216, 256, 1) | step : [469 / 2327]
# End : GT Image of Id 216419  | shape = (216, 256, 1) | step : [470 / 2327]
# End : GT Image of Id 456496  | shape = (216, 256, 1) | step : [471 / 2327]
# End : GT Image of Id 338718  | shape = (216, 256, 1) | step : [472 / 2327]
# End : GT Image of Id 426297  | shape = (216, 256, 1) | step : [473 / 2327]
# End : GT Image of Id 557884  | shape = (216, 256, 1) | step : [474 / 2327]
# End : GT Image of Id  39956  | shape = (216, 256, 1) | step : [475 / 2327]
# End : GT Image of Id  33104  | shape = (216, 256, 1) | step : [476 / 2327]
# End : GT Image of Id 553788  | shape = (216, 256, 1) | step : [477 / 2327]
# End : GT Image of Id 436738  | shape = (216, 256, 1) | step : [478 / 2327]
# End : GT Image of Id 107226  | shape = (216, 256, 1) | step : [479 / 2327]
# End : GT Image of Id  8844   | shape = (216, 256, 1) | step : [480 / 2327]
# End : GT Image of Id  24610  | shape = (216, 256, 1) | step : [481 / 2327]
# End : GT Image of Id 273642  | shape = (216, 256, 1) | step : [482 / 2327]
# End : GT Image of Id 386277  | shape = (216, 256, 1) | step : [483 / 2327]
# End : GT Image of Id 247917  | shape = (216, 256, 1) | step : [484 / 2327]
# End : GT Image of Id 313182  | shape = (216, 256, 1) | step : [485 / 2327]
# End : GT Image of Id 334483  | shape = (216, 256, 1) | step : [486 / 2327]
# End : GT Image of Id 227478  | shape = (216, 256, 1) | step : [487 / 2327]
# End : GT Image of Id  7991   | shape = (216, 256, 1) | step : [488 / 2327]
# End : GT Image of Id 485895  | shape = (216, 256, 1) | step : [489 / 2327]
# End : GT Image of Id  64499  | shape = (216, 256, 1) | step : [490 / 2327]
# End : GT Image of Id 312489  | shape = (216, 256, 1) | step : [491 / 2327]
# End : GT Image of Id 385997  | shape = (216, 256, 1) | step : [492 / 2327]
# End : GT Image of Id 222863  | shape = (216, 256, 1) | step : [493 / 2327]
# End : GT Image of Id 223789  | shape = (216, 256, 1) | step : [494 / 2327]
# End : GT Image of Id 151657  | shape = (216, 256, 1) | step : [495 / 2327]
# End : GT Image of Id 356428  | shape = (216, 256, 1) | step : [496 / 2327]
# End : GT Image of Id 150930  | shape = (216, 256, 1) | step : [497 / 2327]
# End : GT Image of Id 270244  | shape = (216, 256, 1) | step : [498 / 2327]
# End : GT Image of Id 332901  | shape = (216, 256, 1) | step : [499 / 2327]
# End : GT Image of Id 106048  | shape = (216, 256, 1) | step : [500 / 2327]
# End : GT Image of Id 334399  | shape = (216, 256, 1) | step : [501 / 2327]
# End : GT Image of Id 247806  | shape = (216, 256, 1) | step : [502 / 2327]
# End : GT Image of Id 423123  | shape = (216, 256, 1) | step : [503 / 2327]
# End : GT Image of Id 568814  | shape = (216, 256, 1) | step : [504 / 2327]
# End : GT Image of Id 492992  | shape = (216, 256, 1) | step : [505 / 2327]
# End : GT Image of Id 564280  | shape = (216, 256, 1) | step : [506 / 2327]
# End : GT Image of Id 391290  | shape = (216, 256, 1) | step : [507 / 2327]
# End : GT Image of Id  85157  | shape = (216, 256, 1) | step : [508 / 2327]
# End : GT Image of Id 132375  | shape = (216, 256, 1) | step : [509 / 2327]
# End : GT Image of Id  84362  | shape = (216, 256, 1) | step : [510 / 2327]
# End : GT Image of Id 349837  | shape = (216, 256, 1) | step : [511 / 2327]
# End : GT Image of Id 461573  | shape = (216, 256, 1) | step : [512 / 2327]
# End : GT Image of Id 163155  | shape = (216, 256, 1) | step : [513 / 2327]
# End : GT Image of Id 205282  | shape = (216, 256, 1) | step : [514 / 2327]
# End : GT Image of Id 251140  | shape = (216, 256, 1) | step : [515 / 2327]
# End : GT Image of Id 424162  | shape = (216, 256, 1) | step : [516 / 2327]
# End : GT Image of Id 572408  | shape = (216, 256, 1) | step : [517 / 2327]
# End : GT Image of Id 426376  | shape = (216, 256, 1) | step : [518 / 2327]
# End : GT Image of Id 278973  | shape = (216, 256, 1) | step : [519 / 2327]
# End : GT Image of Id 361180  | shape = (216, 256, 1) | step : [520 / 2327]
# End : GT Image of Id 177935  | shape = (216, 256, 1) | step : [521 / 2327]
# End : GT Image of Id 405195  | shape = (216, 256, 1) | step : [522 / 2327]
# End : GT Image of Id 102707  | shape = (216, 256, 1) | step : [523 / 2327]
# End : GT Image of Id 157418  | shape = (216, 256, 1) | step : [524 / 2327]
# End : GT Image of Id  62353  | shape = (216, 256, 1) | step : [525 / 2327]
# End : GT Image of Id  88040  | shape = (216, 256, 1) | step : [526 / 2327]
# End : GT Image of Id 488270  | shape = (216, 256, 1) | step : [527 / 2327]
# End : GT Image of Id 299355  | shape = (216, 256, 1) | step : [528 / 2327]
# End : GT Image of Id 565776  | shape = (216, 256, 1) | step : [529 / 2327]
# End : GT Image of Id 276284  | shape = (216, 256, 1) | step : [530 / 2327]
# End : GT Image of Id 250766  | shape = (216, 256, 1) | step : [531 / 2327]
# End : GT Image of Id 369541  | shape = (216, 256, 1) | step : [532 / 2327]
# End : GT Image of Id  23023  | shape = (216, 256, 1) | step : [533 / 2327]
# End : GT Image of Id 521231  | shape = (216, 256, 1) | step : [534 / 2327]
# End : GT Image of Id 505942  | shape = (216, 256, 1) | step : [535 / 2327]
# End : GT Image of Id 275198  | shape = (216, 256, 1) | step : [536 / 2327]
# End : GT Image of Id 516601  | shape = (216, 256, 1) | step : [537 / 2327]
# End : GT Image of Id  23937  | shape = (216, 256, 1) | step : [538 / 2327]
# End : GT Image of Id 120584  | shape = (216, 256, 1) | step : [539 / 2327]
# End : GT Image of Id 201072  | shape = (216, 256, 1) | step : [540 / 2327]
# End : GT Image of Id  45728  | shape = (216, 256, 1) | step : [541 / 2327]
# End : GT Image of Id 275392  | shape = (216, 256, 1) | step : [542 / 2327]
# End : GT Image of Id  12667  | shape = (216, 256, 1) | step : [543 / 2327]
# End : GT Image of Id 379332  | shape = (216, 256, 1) | step : [544 / 2327]
# End : GT Image of Id 284106  | shape = (216, 256, 1) | step : [545 / 2327]
# End : GT Image of Id 223188  | shape = (216, 256, 1) | step : [546 / 2327]
# End : GT Image of Id 489305  | shape = (216, 256, 1) | step : [547 / 2327]
# End : GT Image of Id  95069  | shape = (216, 256, 1) | step : [548 / 2327]
# End : GT Image of Id 416170  | shape = (216, 256, 1) | step : [549 / 2327]
# End : GT Image of Id 106266  | shape = (216, 256, 1) | step : [550 / 2327]
# End : GT Image of Id 133343  | shape = (216, 256, 1) | step : [551 / 2327]
# End : GT Image of Id 466986  | shape = (216, 256, 1) | step : [552 / 2327]
# End : GT Image of Id 574520  | shape = (216, 256, 1) | step : [553 / 2327]
# End : GT Image of Id 462031  | shape = (216, 256, 1) | step : [554 / 2327]
# End : GT Image of Id 417465  | shape = (216, 256, 1) | step : [555 / 2327]
# End : GT Image of Id 292446  | shape = (216, 256, 1) | step : [556 / 2327]
# End : GT Image of Id 347544  | shape = (216, 256, 1) | step : [557 / 2327]
# End : GT Image of Id 352584  | shape = (216, 256, 1) | step : [558 / 2327]
# End : GT Image of Id 534639  | shape = (216, 256, 1) | step : [559 / 2327]
# End : GT Image of Id 350388  | shape = (216, 256, 1) | step : [560 / 2327]
# End : GT Image of Id 569030  | shape = (216, 256, 1) | step : [561 / 2327]
# End : GT Image of Id 234757  | shape = (216, 256, 1) | step : [562 / 2327]
# End : GT Image of Id 322163  | shape = (216, 256, 1) | step : [563 / 2327]
# End : GT Image of Id 447088  | shape = (216, 256, 1) | step : [564 / 2327]
# End : GT Image of Id 474039  | shape = (216, 256, 1) | step : [565 / 2327]
# End : GT Image of Id 543528  | shape = (216, 256, 1) | step : [566 / 2327]
# End : GT Image of Id 194216  | shape = (216, 256, 1) | step : [567 / 2327]
# End : GT Image of Id 221291  | shape = (216, 256, 1) | step : [568 / 2327]
# End : GT Image of Id 147338  | shape = (216, 256, 1) | step : [569 / 2327]
# End : GT Image of Id 276720  | shape = (216, 256, 1) | step : [570 / 2327]
# End : GT Image of Id 171611  | shape = (216, 256, 1) | step : [571 / 2327]
# End : GT Image of Id  84031  | shape = (216, 256, 1) | step : [572 / 2327]
# End : GT Image of Id 558213  | shape = (216, 256, 1) | step : [573 / 2327]
# End : GT Image of Id 356169  | shape = (216, 256, 1) | step : [574 / 2327]
# End : GT Image of Id 129416  | shape = (216, 256, 1) | step : [575 / 2327]
# End : GT Image of Id 408120  | shape = (216, 256, 1) | step : [576 / 2327]
# End : GT Image of Id  84650  | shape = (216, 256, 1) | step : [577 / 2327]
# End : GT Image of Id 308799  | shape = (216, 256, 1) | step : [578 / 2327]
# End : GT Image of Id 493284  | shape = (216, 256, 1) | step : [579 / 2327]
# End : GT Image of Id 304396  | shape = (216, 256, 1) | step : [580 / 2327]
# End : GT Image of Id 508639  | shape = (216, 256, 1) | step : [581 / 2327]
# End : GT Image of Id 287347  | shape = (216, 256, 1) | step : [582 / 2327]
# End : GT Image of Id 481582  | shape = (216, 256, 1) | step : [583 / 2327]
# End : GT Image of Id 532129  | shape = (216, 256, 1) | step : [584 / 2327]
# End : GT Image of Id 545826  | shape = (216, 256, 1) | step : [585 / 2327]
# End : GT Image of Id 351096  | shape = (216, 256, 1) | step : [586 / 2327]
# End : GT Image of Id 229358  | shape = (216, 256, 1) | step : [587 / 2327]
# End : GT Image of Id 532071  | shape = (216, 256, 1) | step : [588 / 2327]
# End : GT Image of Id 456292  | shape = (216, 256, 1) | step : [589 / 2327]
# End : GT Image of Id 271728  | shape = (216, 256, 1) | step : [590 / 2327]
# End : GT Image of Id 253386  | shape = (216, 256, 1) | step : [591 / 2327]
# End : GT Image of Id 245651  | shape = (216, 256, 1) | step : [592 / 2327]
# End : GT Image of Id 108495  | shape = (216, 256, 1) | step : [593 / 2327]
# End : GT Image of Id 365886  | shape = (216, 256, 1) | step : [594 / 2327]
# End : GT Image of Id 473869  | shape = (216, 256, 1) | step : [595 / 2327]
# End : GT Image of Id 573391  | shape = (216, 256, 1) | step : [596 / 2327]
# End : GT Image of Id 150726  | shape = (216, 256, 1) | step : [597 / 2327]
# End : GT Image of Id 289415  | shape = (216, 256, 1) | step : [598 / 2327]
# End : GT Image of Id 363072  | shape = (216, 256, 1) | step : [599 / 2327]
# End : GT Image of Id 328683  | shape = (216, 256, 1) | step : [600 / 2327]
# End : GT Image of Id 252216  | shape = (216, 256, 1) | step : [601 / 2327]
# End : GT Image of Id 533536  | shape = (216, 256, 1) | step : [602 / 2327]
# End : GT Image of Id 318455  | shape = (216, 256, 1) | step : [603 / 2327]
# End : GT Image of Id 274687  | shape = (216, 256, 1) | step : [604 / 2327]
# End : GT Image of Id 488664  | shape = (216, 256, 1) | step : [605 / 2327]
# End : GT Image of Id 187513  | shape = (216, 256, 1) | step : [606 / 2327]
# End : GT Image of Id 185250  | shape = (216, 256, 1) | step : [607 / 2327]
# End : GT Image of Id 449198  | shape = (216, 256, 1) | step : [608 / 2327]
# End : GT Image of Id 516916  | shape = (216, 256, 1) | step : [609 / 2327]
# End : GT Image of Id 303863  | shape = (216, 256, 1) | step : [610 / 2327]
# End : GT Image of Id 458045  | shape = (216, 256, 1) | step : [611 / 2327]
# End : GT Image of Id 528524  | shape = (216, 256, 1) | step : [612 / 2327]
# End : GT Image of Id  15517  | shape = (216, 256, 1) | step : [613 / 2327]
# End : GT Image of Id 206025  | shape = (216, 256, 1) | step : [614 / 2327]
# End : GT Image of Id 453302  | shape = (216, 256, 1) | step : [615 / 2327]
# End : GT Image of Id 110972  | shape = (216, 256, 1) | step : [616 / 2327]
# End : GT Image of Id 229747  | shape = (216, 256, 1) | step : [617 / 2327]
# End : GT Image of Id 242946  | shape = (216, 256, 1) | step : [618 / 2327]
# End : GT Image of Id  6012   | shape = (216, 256, 1) | step : [619 / 2327]
# End : GT Image of Id 502732  | shape = (216, 256, 1) | step : [620 / 2327]
# End : GT Image of Id 364126  | shape = (216, 256, 1) | step : [621 / 2327]
# End : GT Image of Id  51008  | shape = (216, 256, 1) | step : [622 / 2327]
# End : GT Image of Id 465836  | shape = (216, 256, 1) | step : [623 / 2327]
# End : GT Image of Id  70158  | shape = (216, 256, 1) | step : [624 / 2327]
# End : GT Image of Id 416256  | shape = (216, 256, 1) | step : [625 / 2327]
# End : GT Image of Id 290619  | shape = (216, 256, 1) | step : [626 / 2327]
# End : GT Image of Id 375469  | shape = (216, 256, 1) | step : [627 / 2327]
# End : GT Image of Id  79837  | shape = (216, 256, 1) | step : [628 / 2327]
# End : GT Image of Id 173044  | shape = (216, 256, 1) | step : [629 / 2327]
# End : GT Image of Id 581206  | shape = (216, 256, 1) | step : [630 / 2327]
# End : GT Image of Id 146498  | shape = (216, 256, 1) | step : [631 / 2327]
# End : GT Image of Id 173033  | shape = (216, 256, 1) | step : [632 / 2327]
# End : GT Image of Id 166391  | shape = (216, 256, 1) | step : [633 / 2327]
# End : GT Image of Id 307598  | shape = (216, 256, 1) | step : [634 / 2327]
# End : GT Image of Id 122745  | shape = (216, 256, 1) | step : [635 / 2327]
# End : GT Image of Id 430377  | shape = (216, 256, 1) | step : [636 / 2327]
# End : GT Image of Id  96493  | shape = (216, 256, 1) | step : [637 / 2327]
# End : GT Image of Id 492878  | shape = (216, 256, 1) | step : [638 / 2327]
# End : GT Image of Id 210032  | shape = (216, 256, 1) | step : [639 / 2327]
# End : GT Image of Id 119641  | shape = (216, 256, 1) | step : [640 / 2327]
# End : GT Image of Id 303499  | shape = (216, 256, 1) | step : [641 / 2327]
# End : GT Image of Id  17379  | shape = (216, 256, 1) | step : [642 / 2327]
# End : GT Image of Id 176778  | shape = (216, 256, 1) | step : [643 / 2327]
# End : GT Image of Id 111179  | shape = (216, 256, 1) | step : [644 / 2327]
# End : GT Image of Id  89556  | shape = (216, 256, 1) | step : [645 / 2327]
# ...
# End : GT Image of Id  89296  | shape = (216, 256, 1) | step : [2115 / 2327]
# End : GT Image of Id  75393  | shape = (216, 256, 1) | step : [2116 / 2327]
# End : GT Image of Id 293300  | shape = (216, 256, 1) | step : [2117 / 2327]
# End : GT Image of Id 148508  | shape = (216, 256, 1) | step : [2118 / 2327]
# End : GT Image of Id 226154  | shape = (216, 256, 1) | step : [2119 / 2327]
# End : GT Image of Id 185890  | shape = (216, 256, 1) | step : [2120 / 2327]
# End : GT Image of Id 245915  | shape = (216, 256, 1) | step : [2121 / 2327]
# End : GT Image of Id 359937  | shape = (216, 256, 1) | step : [2122 / 2327]
# End : GT Image of Id 462576  | shape = (216, 256, 1) | step : [2123 / 2327]
# End : GT Image of Id 551660  | shape = (216, 256, 1) | step : [2124 / 2327]
# End : GT Image of Id 187585  | shape = (216, 256, 1) | step : [2125 / 2327]
# End : GT Image of Id 360661  | shape = (216, 256, 1) | step : [2126 / 2327]
# End : GT Image of Id 131273  | shape = (216, 256, 1) | step : [2127 / 2327]
# End : GT Image of Id 272049  | shape = (216, 256, 1) | step : [2128 / 2327]
# End : GT Image of Id 270705  | shape = (216, 256, 1) | step : [2129 / 2327]
# End : GT Image of Id 508730  | shape = (216, 256, 1) | step : [2130 / 2327]
# End : GT Image of Id  79034  | shape = (216, 256, 1) | step : [2131 / 2327]
# End : GT Image of Id 441586  | shape = (216, 256, 1) | step : [2132 / 2327]
# End : GT Image of Id  97337  | shape = (216, 256, 1) | step : [2133 / 2327]
# End : GT Image of Id 318080  | shape = (216, 256, 1) | step : [2134 / 2327]
# End : GT Image of Id 160666  | shape = (216, 256, 1) | step : [2135 / 2327]
# End : GT Image of Id 453634  | shape = (216, 256, 1) | step : [2136 / 2327]
# End : GT Image of Id 384136  | shape = (216, 256, 1) | step : [2137 / 2327]
# End : GT Image of Id 182021  | shape = (216, 256, 1) | step : [2138 / 2327]
# End : GT Image of Id 190007  | shape = (216, 256, 1) | step : [2139 / 2327]
# End : GT Image of Id 210855  | shape = (216, 256, 1) | step : [2140 / 2327]
# End : GT Image of Id 311190  | shape = (216, 256, 1) | step : [2141 / 2327]
# End : GT Image of Id  66706  | shape = (216, 256, 1) | step : [2142 / 2327]
# End : GT Image of Id 339870  | shape = (216, 256, 1) | step : [2143 / 2327]
# End : GT Image of Id 427500  | shape = (216, 256, 1) | step : [2144 / 2327]
# End : GT Image of Id  58655  | shape = (216, 256, 1) | step : [2145 / 2327]
# End : GT Image of Id  86956  | shape = (216, 256, 1) | step : [2146 / 2327]
# End : GT Image of Id 129945  | shape = (216, 256, 1) | step : [2147 / 2327]
# End : GT Image of Id  82085  | shape = (216, 256, 1) | step : [2148 / 2327]
# End : GT Image of Id 451043  | shape = (216, 256, 1) | step : [2149 / 2327]
# End : GT Image of Id 161642  | shape = (216, 256, 1) | step : [2150 / 2327]
# End : GT Image of Id 557501  | shape = (216, 256, 1) | step : [2151 / 2327]
# End : GT Image of Id 361147  | shape = (216, 256, 1) | step : [2152 / 2327]
# End : GT Image of Id 274066  | shape = (216, 256, 1) | step : [2153 / 2327]
# End : GT Image of Id 427338  | shape = (216, 256, 1) | step : [2154 / 2327]
# End : GT Image of Id 287545  | shape = (216, 256, 1) | step : [2155 / 2327]
# End : GT Image of Id 486046  | shape = (216, 256, 1) | step : [2156 / 2327]
# End : GT Image of Id 411817  | shape = (216, 256, 1) | step : [2157 / 2327]
# End : GT Image of Id 166768  | shape = (216, 256, 1) | step : [2158 / 2327]
# End : GT Image of Id 280325  | shape = (216, 256, 1) | step : [2159 / 2327]
# End : GT Image of Id 184978  | shape = (216, 256, 1) | step : [2160 / 2327]
# End : GT Image of Id 430048  | shape = (216, 256, 1) | step : [2161 / 2327]
# End : GT Image of Id 319607  | shape = (216, 256, 1) | step : [2162 / 2327]
# End : GT Image of Id 506178  | shape = (216, 256, 1) | step : [2163 / 2327]
# End : GT Image of Id 101780  | shape = (216, 256, 1) | step : [2164 / 2327]
# End : GT Image of Id 433192  | shape = (216, 256, 1) | step : [2165 / 2327]
# End : GT Image of Id 242678  | shape = (216, 256, 1) | step : [2166 / 2327]
# End : GT Image of Id 176446  | shape = (216, 256, 1) | step : [2167 / 2327]
# End : GT Image of Id  2587   | shape = (216, 256, 1) | step : [2168 / 2327]
# End : GT Image of Id 320664  | shape = (216, 256, 1) | step : [2169 / 2327]
# End : GT Image of Id 336053  | shape = (216, 256, 1) | step : [2170 / 2327]
# End : GT Image of Id 406611  | shape = (216, 256, 1) | step : [2171 / 2327]
# 560371 error
# End : GT Image of Id  8277   | shape = (216, 256, 1) | step : [2173 / 2327]
# End : GT Image of Id  10583  | shape = (216, 256, 1) | step : [2174 / 2327]
# End : GT Image of Id 345252  | shape = (216, 256, 1) | step : [2175 / 2327]
# End : GT Image of Id 306700  | shape = (216, 256, 1) | step : [2176 / 2327]
# End : GT Image of Id 524280  | shape = (216, 256, 1) | step : [2177 / 2327]
# End : GT Image of Id 379533  | shape = (216, 256, 1) | step : [2178 / 2327]
# End : GT Image of Id 137950  | shape = (216, 256, 1) | step : [2179 / 2327]
# End : GT Image of Id 261061  | shape = (216, 256, 1) | step : [2180 / 2327]
# End : GT Image of Id 510329  | shape = (216, 256, 1) | step : [2181 / 2327]
# End : GT Image of Id  63552  | shape = (216, 256, 1) | step : [2182 / 2327]
# End : GT Image of Id 261097  | shape = (216, 256, 1) | step : [2183 / 2327]
# End : GT Image of Id 145591  | shape = (216, 256, 1) | step : [2184 / 2327]
# End : GT Image of Id  67180  | shape = (216, 256, 1) | step : [2185 / 2327]
# End : GT Image of Id 262487  | shape = (216, 256, 1) | step : [2186 / 2327]
# End : GT Image of Id 315187  | shape = (216, 256, 1) | step : [2187 / 2327]
# End : GT Image of Id 113354  | shape = (216, 256, 1) | step : [2188 / 2327]
# End : GT Image of Id  46048  | shape = (216, 256, 1) | step : [2189 / 2327]
# End : GT Image of Id 509258  | shape = (216, 256, 1) | step : [2190 / 2327]
# End : GT Image of Id 259690  | shape = (216, 256, 1) | step : [2191 / 2327]
# End : GT Image of Id 121506  | shape = (216, 256, 1) | step : [2192 / 2327]
# End : GT Image of Id  18833  | shape = (216, 256, 1) | step : [2193 / 2327]
# End : GT Image of Id 550714  | shape = (216, 256, 1) | step : [2194 / 2327]
# End : GT Image of Id 485027  | shape = (216, 256, 1) | step : [2195 / 2327]
# End : GT Image of Id 338624  | shape = (216, 256, 1) | step : [2196 / 2327]
# End : GT Image of Id 428562  | shape = (216, 256, 1) | step : [2197 / 2327]
# End : GT Image of Id  29393  | shape = (216, 256, 1) | step : [2198 / 2327]
# End : GT Image of Id  27972  | shape = (216, 256, 1) | step : [2199 / 2327]
# End : GT Image of Id 279887  | shape = (216, 256, 1) | step : [2200 / 2327]
# End : GT Image of Id 388215  | shape = (216, 256, 1) | step : [2201 / 2327]
# End : GT Image of Id 142585  | shape = (216, 256, 1) | step : [2202 / 2327]
# End : GT Image of Id 322829  | shape = (216, 256, 1) | step : [2203 / 2327]
# End : GT Image of Id 485480  | shape = (216, 256, 1) | step : [2204 / 2327]
# End : GT Image of Id 341094  | shape = (216, 256, 1) | step : [2205 / 2327]
# End : GT Image of Id 534041  | shape = (216, 256, 1) | step : [2206 / 2327]
# End : GT Image of Id 323799  | shape = (216, 256, 1) | step : [2207 / 2327]
# End : GT Image of Id 164115  | shape = (216, 256, 1) | step : [2208 / 2327]
# End : GT Image of Id 229311  | shape = (216, 256, 1) | step : [2209 / 2327]
# End : GT Image of Id 459757  | shape = (216, 256, 1) | step : [2210 / 2327]
# End : GT Image of Id 146825  | shape = (216, 256, 1) | step : [2211 / 2327]
# End : GT Image of Id 182441  | shape = (216, 256, 1) | step : [2212 / 2327]
# End : GT Image of Id 233567  | shape = (216, 256, 1) | step : [2213 / 2327]
# End : GT Image of Id  90208  | shape = (216, 256, 1) | step : [2214 / 2327]
# End : GT Image of Id 161820  | shape = (216, 256, 1) | step : [2215 / 2327]
# End : GT Image of Id 359855  | shape = (216, 256, 1) | step : [2216 / 2327]
# End : GT Image of Id 315492  | shape = (216, 256, 1) | step : [2217 / 2327]
# End : GT Image of Id 308753  | shape = (216, 256, 1) | step : [2218 / 2327]
# End : GT Image of Id 509656  | shape = (216, 256, 1) | step : [2219 / 2327]
# End : GT Image of Id  66886  | shape = (216, 256, 1) | step : [2220 / 2327]
# End : GT Image of Id 400044  | shape = (216, 256, 1) | step : [2221 / 2327]
# End : GT Image of Id  85576  | shape = (216, 256, 1) | step : [2222 / 2327]
# End : GT Image of Id 424545  | shape = (216, 256, 1) | step : [2223 / 2327]
# End : GT Image of Id 376307  | shape = (216, 256, 1) | step : [2224 / 2327]
# End : GT Image of Id 381360  | shape = (216, 256, 1) | step : [2225 / 2327]
# End : GT Image of Id  66817  | shape = (216, 256, 1) | step : [2226 / 2327]
# End : GT Image of Id 404191  | shape = (216, 256, 1) | step : [2227 / 2327]
# End : GT Image of Id 143998  | shape = (216, 256, 1) | step : [2228 / 2327]
# End : GT Image of Id 496571  | shape = (216, 256, 1) | step : [2229 / 2327]
# End : GT Image of Id 231879  | shape = (216, 256, 1) | step : [2230 / 2327]
# End : GT Image of Id 288584  | shape = (216, 256, 1) | step : [2231 / 2327]
# End : GT Image of Id 112798  | shape = (216, 256, 1) | step : [2232 / 2327]
# End : GT Image of Id 409268  | shape = (216, 256, 1) | step : [2233 / 2327]
# End : GT Image of Id 383838  | shape = (216, 256, 1) | step : [2234 / 2327]
# End : GT Image of Id  3661   | shape = (216, 256, 1) | step : [2235 / 2327]
# End : GT Image of Id 280891  | shape = (216, 256, 1) | step : [2236 / 2327]
# End : GT Image of Id  1425   | shape = (216, 256, 1) | step : [2237 / 2327]
# End : GT Image of Id 163290  | shape = (216, 256, 1) | step : [2238 / 2327]
# End : GT Image of Id 198489  | shape = (216, 256, 1) | step : [2239 / 2327]
# End : GT Image of Id 324927  | shape = (216, 256, 1) | step : [2240 / 2327]
# End : GT Image of Id 561335  | shape = (216, 256, 1) | step : [2241 / 2327]
# End : GT Image of Id 442323  | shape = (216, 256, 1) | step : [2242 / 2327]
# End : GT Image of Id  15254  | shape = (216, 256, 1) | step : [2243 / 2327]
# End : GT Image of Id 309452  | shape = (216, 256, 1) | step : [2244 / 2327]
# End : GT Image of Id 466156  | shape = (216, 256, 1) | step : [2245 / 2327]
# End : GT Image of Id 552842  | shape = (216, 256, 1) | step : [2246 / 2327]
# End : GT Image of Id   885   | shape = (216, 256, 1) | step : [2247 / 2327]
# End : GT Image of Id 360951  | shape = (216, 256, 1) | step : [2248 / 2327]
# End : GT Image of Id 529528  | shape = (216, 256, 1) | step : [2249 / 2327]
# End : GT Image of Id 289659  | shape = (216, 256, 1) | step : [2250 / 2327]
# End : GT Image of Id 295420  | shape = (216, 256, 1) | step : [2251 / 2327]
# End : GT Image of Id  80340  | shape = (216, 256, 1) | step : [2252 / 2327]
# End : GT Image of Id 165257  | shape = (216, 256, 1) | step : [2253 / 2327]
# End : GT Image of Id 424721  | shape = (216, 256, 1) | step : [2254 / 2327]
# End : GT Image of Id 147740  | shape = (216, 256, 1) | step : [2255 / 2327]
# End : GT Image of Id 182805  | shape = (216, 256, 1) | step : [2256 / 2327]
# End : GT Image of Id 231237  | shape = (216, 256, 1) | step : [2257 / 2327]
# End : GT Image of Id 357903  | shape = (216, 256, 1) | step : [2258 / 2327]
# End : GT Image of Id  30213  | shape = (216, 256, 1) | step : [2259 / 2327]
# End : GT Image of Id 297595  | shape = (216, 256, 1) | step : [2260 / 2327]
# End : GT Image of Id 495054  | shape = (216, 256, 1) | step : [2261 / 2327]
# End : GT Image of Id  36494  | shape = (216, 256, 1) | step : [2262 / 2327]
# End : GT Image of Id  95155  | shape = (216, 256, 1) | step : [2263 / 2327]
# End : GT Image of Id 387383  | shape = (216, 256, 1) | step : [2264 / 2327]
# End : GT Image of Id  89045  | shape = (216, 256, 1) | step : [2265 / 2327]
# End : GT Image of Id 396568  | shape = (216, 256, 1) | step : [2266 / 2327]
# End : GT Image of Id 253433  | shape = (216, 256, 1) | step : [2267 / 2327]
# End : GT Image of Id 311909  | shape = (216, 256, 1) | step : [2268 / 2327]
# End : GT Image of Id 169996  | shape = (216, 256, 1) | step : [2269 / 2327]
# End : GT Image of Id 356261  | shape = (216, 256, 1) | step : [2270 / 2327]
# End : GT Image of Id 459272  | shape = (216, 256, 1) | step : [2271 / 2327]
# End : GT Image of Id 246883  | shape = (216, 256, 1) | step : [2272 / 2327]
# End : GT Image of Id 142472  | shape = (216, 256, 1) | step : [2273 / 2327]
# End : GT Image of Id 555005  | shape = (216, 256, 1) | step : [2274 / 2327]
# End : GT Image of Id 143931  | shape = (216, 256, 1) | step : [2275 / 2327]
# End : GT Image of Id 122046  | shape = (216, 256, 1) | step : [2276 / 2327]
# End : GT Image of Id 245513  | shape = (216, 256, 1) | step : [2277 / 2327]
# End : GT Image of Id 389812  | shape = (216, 256, 1) | step : [2278 / 2327]
# End : GT Image of Id 174231  | shape = (216, 256, 1) | step : [2279 / 2327]
# End : GT Image of Id 145665  | shape = (216, 256, 1) | step : [2280 / 2327]
# End : GT Image of Id  83540  | shape = (216, 256, 1) | step : [2281 / 2327]
# End : GT Image of Id  5037   | shape = (216, 256, 1) | step : [2282 / 2327]
# End : GT Image of Id 574315  | shape = (216, 256, 1) | step : [2283 / 2327]
# End : GT Image of Id 462371  | shape = (216, 256, 1) | step : [2284 / 2327]
# End : GT Image of Id 539962  | shape = (216, 256, 1) | step : [2285 / 2327]
# End : GT Image of Id 191471  | shape = (216, 256, 1) | step : [2286 / 2327]
# End : GT Image of Id 353051  | shape = (216, 256, 1) | step : [2287 / 2327]
# 209222 error
# End : GT Image of Id 428280  | shape = (216, 256, 1) | step : [2289 / 2327]
# End : GT Image of Id 219485  | shape = (216, 256, 1) | step : [2290 / 2327]
# End : GT Image of Id  40757  | shape = (216, 256, 1) | step : [2291 / 2327]
# End : GT Image of Id 405691  | shape = (216, 256, 1) | step : [2292 / 2327]
# End : GT Image of Id 501523  | shape = (216, 256, 1) | step : [2293 / 2327]
# End : GT Image of Id 153632  | shape = (216, 256, 1) | step : [2294 / 2327]
# 41488 error
# End : GT Image of Id 526751  | shape = (216, 256, 1) | step : [2296 / 2327]
# End : GT Image of Id 197004  | shape = (216, 256, 1) | step : [2297 / 2327]
# End : GT Image of Id  32735  | shape = (216, 256, 1) | step : [2298 / 2327]
# End : GT Image of Id 384850  | shape = (216, 256, 1) | step : [2299 / 2327]
# End : GT Image of Id 330790  | shape = (216, 256, 1) | step : [2300 / 2327]
# End : GT Image of Id 352491  | shape = (216, 256, 1) | step : [2301 / 2327]
# End : GT Image of Id 376900  | shape = (216, 256, 1) | step : [2302 / 2327]
# End : GT Image of Id 368900  | shape = (216, 256, 1) | step : [2303 / 2327]
# End : GT Image of Id 117492  | shape = (216, 256, 1) | step : [2304 / 2327]
# End : GT Image of Id  41872  | shape = (216, 256, 1) | step : [2305 / 2327]
# End : GT Image of Id 228144  | shape = (216, 256, 1) | step : [2306 / 2327]
# End : GT Image of Id 433980  | shape = (216, 256, 1) | step : [2307 / 2327]
# End : GT Image of Id 346905  | shape = (216, 256, 1) | step : [2308 / 2327]
# End : GT Image of Id 577584  | shape = (216, 256, 1) | step : [2309 / 2327]
# End : GT Image of Id  81738  | shape = (216, 256, 1) | step : [2310 / 2327]
# End : GT Image of Id 321333  | shape = (216, 256, 1) | step : [2311 / 2327]
# End : GT Image of Id 415238  | shape = (216, 256, 1) | step : [2312 / 2327]
# End : GT Image of Id 132116  | shape = (216, 256, 1) | step : [2313 / 2327]
# End : GT Image of Id 158548  | shape = (216, 256, 1) | step : [2314 / 2327]
# End : GT Image of Id 513688  | shape = (216, 256, 1) | step : [2315 / 2327]
# End : GT Image of Id 335328  | shape = (216, 256, 1) | step : [2316 / 2327]
# End : GT Image of Id 314294  | shape = (216, 256, 1) | step : [2317 / 2327]
# 481404 error
# End : GT Image of Id 320425  | shape = (216, 256, 1) | step : [2319 / 2327]
# End : GT Image of Id 365745  | shape = (216, 256, 1) | step : [2320 / 2327]
# End : GT Image of Id 463918  | shape = (216, 256, 1) | step : [2321 / 2327]
# End : GT Image of Id 114871  | shape = (216, 256, 1) | step : [2322 / 2327]
# End : GT Image of Id 119038  | shape = (216, 256, 1) | step : [2323 / 2327]
# End : GT Image of Id  62808  | shape = (216, 256, 1) | step : [2324 / 2327]
# End : GT Image of Id 578922  | shape = (216, 256, 1) | step : [2325 / 2327]
# End : GT Image of Id 231527  | shape = (216, 256, 1) | step : [2326 / 2327]
# End : GT Image of Id 212226  | shape = (216, 256, 1) | step : [2327 / 2327]

# %%
# np.save('gt_img_116.npy', np.asarray(gt_img))

# %%
input_img = np.array(input_img)
gt_img = np.array(gt_img)

# %%
print(input_img.shape, gt_img.shape)
# Out:
# (2299, 216, 256, 3) (2299, 216, 256, 1)

# %% [markdown]
# # Compile

# %%
from keras import backend as K

__EPS = 1e-5
def image_categorical_crossentropy(y_true, y_pred):
    y_pred = K.clip(y_pred, __EPS, 1 - __EPS)
    return -K.mean(y_true * K.log(y_pred) + (1 - y_true) * K.log(1 - y_pred))

# %%
u_net.compile(optimizer = 'sgd', loss = image_categorical_crossentropy , metrics = ['accuracy'])

# %% [markdown]
# # Training

# %%
u_net.fit(x = input_img, y = gt_img, epochs = 10)
# Out:
# Epoch 1/10
# 1696/2299 [=====================>........] - ETA: 24s - loss: -103.8539 - acc: 0.0761
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-edbc4c34e0eb> in <module>()
# ----> 1 u_net.fit(x = input_img, y = gt_img, epochs = 10)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     885     try:
#     886       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 887                          run_metadata_ptr)
#     888       if run_metadata:
#     889         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1108     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1109       results = self._do_run(handle, final_targets, final_fetches,
# -> 1110                              feed_dict_tensor, options, run_metadata)
#    1111     else:
#    1112       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1284     if handle is None:
#    1285       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1286                            run_metadata)
#    1287     else:
#    1288       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1290   def _do_call(self, fn, *args):
#    1291     try:
# -> 1292       return fn(*args)
#    1293     except errors.OpError as e:
#    1294       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1275       self._extend_graph()
#    1276       return self._call_tf_sessionrun(
# -> 1277           options, feed_dict, fetch_list, target_list, run_metadata)
#    1278
#    1279     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1365     return tf_session.TF_SessionRun_wrapper(
#    1366         self._session, options, feed_dict, fetch_list, target_list,
# -> 1367         run_metadata)
#    1368
#    1369   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
